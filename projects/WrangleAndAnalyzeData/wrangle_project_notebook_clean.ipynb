# %%
import pandas as pd
import numpy as np
import json

# %%
df_archive = pd.read_csv('twitter-archive-enhanced.csv')
df_archive.head(3)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
#
#    rating_denominator     name doggo floofer pupper puppo
# 0                  10  Phineas  None    None   None  None
# 1                  10    Tilly  None    None   None  None
# 2                  10   Archie  None    None   None  None

# %%
df_class = pd.read_csv('twitter_image_class.csv')
df_class.head(3)
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665    True    Shetland_sheepdog  0.061428    True
# 1  0.074192    True  Rhodesian_ridgeback  0.072010    True
# 2  0.138584    True           bloodhound  0.116197    True

# %%
df_status = pd.read_csv('twitter_status_dogs.csv')
df_status.head(3)
# Out:
#              tweet_id                                         text_check  \
# 0  892420643555336193  This is Phineas. He's a mystical boy. Only eve...
# 1  892177421306343426  This is Tilly. She's just checking pup on you....
# 2  891815181378084864  This is Archie. He is a rare Norwegian Pouncin...
#
#                                   dog_picture_url  \
# 0  http://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
# 1  http://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2  http://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
#
#                                        tweet_web_url  favourite_count  \
# 0  https://twitter.com/dog_rates/status/892420643...            37434
# 1  https://twitter.com/dog_rates/status/892177421...            32164
# 2  https://twitter.com/dog_rates/status/891815181...            24251
#
#    retweet_count retweet_status_id_api
# 0           8138                  None
# 1           6029                  None
# 2           3991                  None

# %%
df_archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# puppo                         2356 non-null object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %%
df_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
df_status.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2335 entries, 0 to 2334
# Data columns (total 7 columns):
# tweet_id                 2335 non-null int64
# text_check               2335 non-null object
# dog_picture_url          2335 non-null object
# tweet_web_url            2335 non-null object
# favourite_count          2335 non-null int64
# retweet_count            2335 non-null int64
# retweet_status_id_api    2335 non-null object
# dtypes: int64(3), object(4)
# memory usage: 127.8+ KB

# %%
all_columns = pd.Series(list(df_archive) + list(df_class) + list(df_status))
all_columns[all_columns.duplicated()]
# Out:
# 17    tweet_id
# 29    tweet_id
# dtype: object

# %% [markdown]
# #### Good that names of columns are not duplicated apart from tweet_id on which the tables can be joined;  but there are actually duplicating contents in several columns (eg text in `df_archive` and text_check in `df_status` )

# %% [markdown]
# ### Tidying

# %% [markdown]
# Joining `df_archive` and `df_status`, which can sit in one table (following cleaning), complying with tidyness protocol; also once they do, it will be easier to examine the following
#   - dropping rows that have no *favourite_rating* and *retween_count* (this is because those tweets were deleted, and where  subsequntly not received from Twitter API
#   - checking tweet text is correct for each tweet (comparing two columns that store tweet text, deciding which to keep),
#   - similarly checking other potentially duplicated columns, including tweet_url (columns `expanded_urls` and `tweet_web_url`) and retweet_id (columns `retweeted_status_id` and `retween_status_id_api`)
#   - converting the `retweeted_status_id` column to integer (np.int64), in line with tweet_id
#   - checking ratings (`rating_numerator` and `rating_denominator`) are correctly imported to ratings columns (from tweet text)
#   - creating one column for 'dog_stages' (from the four "dummy" columns of `doggo`, `floofer`, `pupper`, `puppo`)
#   - checking 'dog stages' are all correctly extracted
#   - identifying and dropping columns that are retweets (explicitly not required to be included in the project)
#   - checking other cleanliness issues
#
# It seems that the image classification table `df_class` could also be joined without causing tidyness issues, that said, since it is such a different "unit" of information, with its own independent source (ie classification model output), will keep it separate for now.

# %%
tweet_clean = pd.merge(df_archive, df_status,
                            on=['tweet_id'], how='left')

# %%
tweet_clean
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# 13    889638837579907072                    NaN                  NaN
# 14    889531135344209921                    NaN                  NaN
# 15    889278841981685760                    NaN                  NaN
# 16    888917238123831296                    NaN                  NaN
# 17    888804989199671297                    NaN                  NaN
# 18    888554962724278272                    NaN                  NaN
# 19    888202515573088257                    NaN                  NaN
# 20    888078434458587136                    NaN                  NaN
# 21    887705289381826560                    NaN                  NaN
# 22    887517139158093824                    NaN                  NaN
# 23    887473957103951883                    NaN                  NaN
# 24    887343217045368832                    NaN                  NaN
# 25    887101392804085760                    NaN                  NaN
# 26    886983233522544640                    NaN                  NaN
# 27    886736880519319552                    NaN                  NaN
# 28    886680336477933568                    NaN                  NaN
# 29    886366144734445568                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2326  666411507551481857                    NaN                  NaN
# 2327  666407126856765440                    NaN                  NaN
# 2328  666396247373291520                    NaN                  NaN
# 2329  666373753744588802                    NaN                  NaN
# 2330  666362758909284353                    NaN                  NaN
# 2331  666353288456101888                    NaN                  NaN
# 2332  666345417576210432                    NaN                  NaN
# 2333  666337882303524864                    NaN                  NaN
# 2334  666293911632134144                    NaN                  NaN
# 2335  666287406224695296                    NaN                  NaN
# 2336  666273097616637952                    NaN                  NaN
# 2337  666268910803644416                    NaN                  NaN
# 2338  666104133288665088                    NaN                  NaN
# 2339  666102155909144576                    NaN                  NaN
# 2340  666099513787052032                    NaN                  NaN
# 2341  666094000022159362                    NaN                  NaN
# 2342  666082916733198337                    NaN                  NaN
# 2343  666073100786774016                    NaN                  NaN
# 2344  666071193221509120                    NaN                  NaN
# 2345  666063827256086533                    NaN                  NaN
# 2346  666058600524156928                    NaN                  NaN
# 2347  666057090499244032                    NaN                  NaN
# 2348  666055525042405380                    NaN                  NaN
# 2349  666051853826850816                    NaN                  NaN
# 2350  666050758794694657                    NaN                  NaN
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# 3     2017-07-30 15:58:51 +0000
# 4     2017-07-29 16:00:24 +0000
# 5     2017-07-29 00:08:17 +0000
# 6     2017-07-28 16:27:12 +0000
# 7     2017-07-28 00:22:40 +0000
# 8     2017-07-27 16:25:51 +0000
# 9     2017-07-26 15:59:51 +0000
# 10    2017-07-26 00:31:25 +0000
# 11    2017-07-25 16:11:53 +0000
# 12    2017-07-25 01:55:32 +0000
# 13    2017-07-25 00:10:02 +0000
# 14    2017-07-24 17:02:04 +0000
# 15    2017-07-24 00:19:32 +0000
# 16    2017-07-23 00:22:39 +0000
# 17    2017-07-22 16:56:37 +0000
# 18    2017-07-22 00:23:06 +0000
# 19    2017-07-21 01:02:36 +0000
# 20    2017-07-20 16:49:33 +0000
# 21    2017-07-19 16:06:48 +0000
# 22    2017-07-19 03:39:09 +0000
# 23    2017-07-19 00:47:34 +0000
# 24    2017-07-18 16:08:03 +0000
# 25    2017-07-18 00:07:08 +0000
# 26    2017-07-17 16:17:36 +0000
# 27    2017-07-16 23:58:41 +0000
# 28    2017-07-16 20:14:00 +0000
# 29    2017-07-15 23:25:31 +0000
# ...                         ...
# 2326  2015-11-17 00:24:19 +0000
# 2327  2015-11-17 00:06:54 +0000
# 2328  2015-11-16 23:23:41 +0000
# 2329  2015-11-16 21:54:18 +0000
# 2330  2015-11-16 21:10:36 +0000
# 2331  2015-11-16 20:32:58 +0000
# 2332  2015-11-16 20:01:42 +0000
# 2333  2015-11-16 19:31:45 +0000
# 2334  2015-11-16 16:37:02 +0000
# 2335  2015-11-16 16:11:11 +0000
# 2336  2015-11-16 15:14:19 +0000
# 2337  2015-11-16 14:57:41 +0000
# 2338  2015-11-16 04:02:55 +0000
# 2339  2015-11-16 03:55:04 +0000
# 2340  2015-11-16 03:44:34 +0000
# 2341  2015-11-16 03:22:39 +0000
# 2342  2015-11-16 02:38:37 +0000
# 2343  2015-11-16 01:59:36 +0000
# 2344  2015-11-16 01:52:02 +0000
# 2345  2015-11-16 01:22:45 +0000
# 2346  2015-11-16 01:01:59 +0000
# 2347  2015-11-16 00:55:59 +0000
# 2348  2015-11-16 00:49:46 +0000
# 2349  2015-11-16 00:35:11 +0000
# 2350  2015-11-16 00:30:50 +0000
# 2351  2015-11-16 00:24:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/iphone" r...
# 5     <a href="http://twitter.com/download/iphone" r...
# 6     <a href="http://twitter.com/download/iphone" r...
# 7     <a href="http://twitter.com/download/iphone" r...
# 8     <a href="http://twitter.com/download/iphone" r...
# 9     <a href="http://twitter.com/download/iphone" r...
# 10    <a href="http://twitter.com/download/iphone" r...
# 11    <a href="http://twitter.com/download/iphone" r...
# 12    <a href="http://twitter.com/download/iphone" r...
# 13    <a href="http://twitter.com/download/iphone" r...
# 14    <a href="http://twitter.com/download/iphone" r...
# 15    <a href="http://twitter.com/download/iphone" r...
# 16    <a href="http://twitter.com/download/iphone" r...
# 17    <a href="http://twitter.com/download/iphone" r...
# 18    <a href="http://twitter.com/download/iphone" r...
# 19    <a href="http://twitter.com/download/iphone" r...
# 20    <a href="http://twitter.com/download/iphone" r...
# 21    <a href="http://twitter.com/download/iphone" r...
# 22    <a href="http://twitter.com/download/iphone" r...
# 23    <a href="http://twitter.com/download/iphone" r...
# 24    <a href="http://twitter.com/download/iphone" r...
# 25    <a href="http://twitter.com/download/iphone" r...
# 26    <a href="http://twitter.com/download/iphone" r...
# 27    <a href="http://twitter.com/download/iphone" r...
# 28    <a href="http://twitter.com/download/iphone" r...
# 29    <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 2326  <a href="http://twitter.com/download/iphone" r...
# 2327  <a href="http://twitter.com/download/iphone" r...
# 2328  <a href="http://twitter.com/download/iphone" r...
# 2329  <a href="http://twitter.com/download/iphone" r...
# 2330  <a href="http://twitter.com/download/iphone" r...
# 2331  <a href="http://twitter.com/download/iphone" r...
# 2332  <a href="http://twitter.com/download/iphone" r...
# 2333  <a href="http://twitter.com/download/iphone" r...
# 2334  <a href="http://twitter.com/download/iphone" r...
# 2335  <a href="http://twitter.com/download/iphone" r...
# 2336  <a href="http://twitter.com/download/iphone" r...
# 2337  <a href="http://twitter.com/download/iphone" r...
# 2338  <a href="http://twitter.com/download/iphone" r...
# 2339  <a href="http://twitter.com/download/iphone" r...
# 2340  <a href="http://twitter.com/download/iphone" r...
# 2341  <a href="http://twitter.com/download/iphone" r...
# 2342  <a href="http://twitter.com/download/iphone" r...
# 2343  <a href="http://twitter.com/download/iphone" r...
# 2344  <a href="http://twitter.com/download/iphone" r...
# 2345  <a href="http://twitter.com/download/iphone" r...
# 2346  <a href="http://twitter.com/download/iphone" r...
# 2347  <a href="http://twitter.com/download/iphone" r...
# 2348  <a href="http://twitter.com/download/iphone" r...
# 2349  <a href="http://twitter.com/download/iphone" r...
# 2350  <a href="http://twitter.com/download/iphone" r...
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 0     This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1     This is Tilly. She's just checking pup on you....                  NaN
# 2     This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3     This is Darla. She commenced a snooze mid meal...                  NaN
# 4     This is Franklin. He would like you to stop ca...                  NaN
# 5     Here we have a majestic great white breaching ...                  NaN
# 6     Meet Jax. He enjoys ice cream so much he gets ...                  NaN
# 7     When you watch your owner call another dog a g...                  NaN
# 8     This is Zoey. She doesn't want to be one of th...                  NaN
# 9     This is Cassie. She is a college pup. Studying...                  NaN
# 10    This is Koda. He is a South Australian decksha...                  NaN
# 11    This is Bruno. He is a service shark. Only get...                  NaN
# 12    Here's a puppo that seems to be on the fence a...                  NaN
# 13    This is Ted. He does his best. Sometimes that'...                  NaN
# 14    This is Stuart. He's sporting his favorite fan...                  NaN
# 15    This is Oliver. You're witnessing one of his m...                  NaN
# 16    This is Jim. He found a fren. Taught him how t...                  NaN
# 17    This is Zeke. He has a new stick. Very proud o...                  NaN
# 18    This is Ralphus. He's powering up. Attempting ...                  NaN
# 19    RT @dog_rates: This is Canela. She attempted s...         8.874740e+17
# 20    This is Gerald. He was just told he didn't get...                  NaN
# 21    This is Jeffrey. He has a monopoly on the pool...                  NaN
# 22    I've yet to rate a Venezuelan Hover Wiener. Th...                  NaN
# 23    This is Canela. She attempted some fancy porch...                  NaN
# 24    You may not have known you needed to see this ...                  NaN
# 25    This... is a Jubilant Antarctic House Bear. We...                  NaN
# 26    This is Maya. She's very shy. Rarely leaves he...                  NaN
# 27    This is Mingus. He's a wonderful father to his...                  NaN
# 28    This is Derek. He's late for a dog meeting. 13...                  NaN
# 29    This is Roscoe. Another pupper fallen victim t...                  NaN
# ...                                                 ...                  ...
# 2326  This is quite the dog. Gets really excited whe...                  NaN
# 2327  This is a southern Vesuvius bumblegruff. Can d...                  NaN
# 2328  Oh goodness. A super rare northeast Qdoba kang...                  NaN
# 2329  Those are sunglasses and a jean jacket. 11/10 ...                  NaN
# 2330  Unique dog here. Very small. Lives in containe...                  NaN
# 2331  Here we have a mixed Asiago from the Galápagos...                  NaN
# 2332  Look at this jokester thinking seat belt laws ...                  NaN
# 2333  This is an extremely rare horned Parthenon. No...                  NaN
# 2334  This is a funny dog. Weird toes. Won't come do...                  NaN
# 2335  This is an Albanian 3 1/2 legged  Episcopalian...                  NaN
# 2336     Can take selfies 11/10 https://t.co/ws2AMaNwPW                  NaN
# 2337  Very concerned about fellow dog trapped in com...                  NaN
# 2338  Not familiar with this breed. No tail (weird)....                  NaN
# 2339  Oh my. Here you are seeing an Adobe Setter giv...                  NaN
# 2340  Can stand on stump for what seems like a while...                  NaN
# 2341  This appears to be a Mongolian Presbyterian mi...                  NaN
# 2342  Here we have a well-established sunblockerspan...                  NaN
# 2343  Let's hope this flight isn't Malaysian (lol). ...                  NaN
# 2344  Here we have a northern speckled Rhododendron....                  NaN
# 2345  This is the happiest dog you will ever see. Ve...                  NaN
# 2346  Here is the Rand Paul of retrievers folks! He'...                  NaN
# 2347  My oh my. This is a rare blond Canadian terrie...                  NaN
# 2348  Here is a Siberian heavily armored polar bear ...                  NaN
# 2349  This is an odd dog. Hard on the outside but lo...                  NaN
# 2350  This is a truly beautiful English Wilson Staff...                  NaN
# 2351  Here we have a 1949 1st generation vulpix. Enj...                  NaN
# 2352  This is a purebred Piers Morgan. Loves to Netf...                  NaN
# 2353  Here is a very happy pup. Big fan of well-main...                  NaN
# 2354  This is a western brown Mitsubishi terrier. Up...                  NaN
# 2355  Here we have a Japanese Irish Setter. Lost eye...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# 5                          NaN                        NaN
# 6                          NaN                        NaN
# 7                          NaN                        NaN
# 8                          NaN                        NaN
# 9                          NaN                        NaN
# 10                         NaN                        NaN
# 11                         NaN                        NaN
# 12                         NaN                        NaN
# 13                         NaN                        NaN
# 14                         NaN                        NaN
# 15                         NaN                        NaN
# 16                         NaN                        NaN
# 17                         NaN                        NaN
# 18                         NaN                        NaN
# 19                4.196984e+09  2017-07-19 00:47:34 +0000
# 20                         NaN                        NaN
# 21                         NaN                        NaN
# 22                         NaN                        NaN
# 23                         NaN                        NaN
# 24                         NaN                        NaN
# 25                         NaN                        NaN
# 26                         NaN                        NaN
# 27                         NaN                        NaN
# 28                         NaN                        NaN
# 29                         NaN                        NaN
# ...                        ...                        ...
# 2326                       NaN                        NaN
# 2327                       NaN                        NaN
# 2328                       NaN                        NaN
# 2329                       NaN                        NaN
# 2330                       NaN                        NaN
# 2331                       NaN                        NaN
# 2332                       NaN                        NaN
# 2333                       NaN                        NaN
# 2334                       NaN                        NaN
# 2335                       NaN                        NaN
# 2336                       NaN                        NaN
# 2337                       NaN                        NaN
# 2338                       NaN                        NaN
# 2339                       NaN                        NaN
# 2340                       NaN                        NaN
# 2341                       NaN                        NaN
# 2342                       NaN                        NaN
# 2343                       NaN                        NaN
# 2344                       NaN                        NaN
# 2345                       NaN                        NaN
# 2346                       NaN                        NaN
# 2347                       NaN                        NaN
# 2348                       NaN                        NaN
# 2349                       NaN                        NaN
# 2350                       NaN                        NaN
# 2351                       NaN                        NaN
# 2352                       NaN                        NaN
# 2353                       NaN                        NaN
# 2354                       NaN                        NaN
# 2355                       NaN                        NaN
#
#                                           expanded_urls  ...  doggo  floofer  \
# 0     https://twitter.com/dog_rates/status/892420643...  ...   None     None
# 1     https://twitter.com/dog_rates/status/892177421...  ...   None     None
# 2     https://twitter.com/dog_rates/status/891815181...  ...   None     None
# 3     https://twitter.com/dog_rates/status/891689557...  ...   None     None
# 4     https://twitter.com/dog_rates/status/891327558...  ...   None     None
# 5     https://twitter.com/dog_rates/status/891087950...  ...   None     None
# 6     https://gofundme.com/ydvmve-surgery-for-jax,ht...  ...   None     None
# 7     https://twitter.com/dog_rates/status/890729181...  ...   None     None
# 8     https://twitter.com/dog_rates/status/890609185...  ...   None     None
# 9     https://twitter.com/dog_rates/status/890240255...  ...  doggo     None
# 10    https://twitter.com/dog_rates/status/890006608...  ...   None     None
# 11    https://twitter.com/dog_rates/status/889880896...  ...   None     None
# 12    https://twitter.com/dog_rates/status/889665388...  ...   None     None
# 13    https://twitter.com/dog_rates/status/889638837...  ...   None     None
# 14    https://twitter.com/dog_rates/status/889531135...  ...   None     None
# 15    https://twitter.com/dog_rates/status/889278841...  ...   None     None
# 16    https://twitter.com/dog_rates/status/888917238...  ...   None     None
# 17    https://twitter.com/dog_rates/status/888804989...  ...   None     None
# 18    https://twitter.com/dog_rates/status/888554962...  ...   None     None
# 19    https://twitter.com/dog_rates/status/887473957...  ...   None     None
# 20    https://twitter.com/dog_rates/status/888078434...  ...   None     None
# 21    https://twitter.com/dog_rates/status/887705289...  ...   None     None
# 22    https://twitter.com/dog_rates/status/887517139...  ...   None     None
# 23    https://twitter.com/dog_rates/status/887473957...  ...   None     None
# 24    https://twitter.com/dog_rates/status/887343217...  ...   None     None
# 25    https://twitter.com/dog_rates/status/887101392...  ...   None     None
# 26    https://twitter.com/dog_rates/status/886983233...  ...   None     None
# 27    https://www.gofundme.com/mingusneedsus,https:/...  ...   None     None
# 28    https://twitter.com/dog_rates/status/886680336...  ...   None     None
# 29    https://twitter.com/dog_rates/status/886366144...  ...   None     None
# ...                                                 ...  ...    ...      ...
# 2326  https://twitter.com/dog_rates/status/666411507...  ...   None     None
# 2327  https://twitter.com/dog_rates/status/666407126...  ...   None     None
# 2328  https://twitter.com/dog_rates/status/666396247...  ...   None     None
# 2329  https://twitter.com/dog_rates/status/666373753...  ...   None     None
# 2330  https://twitter.com/dog_rates/status/666362758...  ...   None     None
# 2331  https://twitter.com/dog_rates/status/666353288...  ...   None     None
# 2332  https://twitter.com/dog_rates/status/666345417...  ...   None     None
# 2333  https://twitter.com/dog_rates/status/666337882...  ...   None     None
# 2334  https://twitter.com/dog_rates/status/666293911...  ...   None     None
# 2335  https://twitter.com/dog_rates/status/666287406...  ...   None     None
# 2336  https://twitter.com/dog_rates/status/666273097...  ...   None     None
# 2337  https://twitter.com/dog_rates/status/666268910...  ...   None     None
# 2338  https://twitter.com/dog_rates/status/666104133...  ...   None     None
# 2339  https://twitter.com/dog_rates/status/666102155...  ...   None     None
# 2340  https://twitter.com/dog_rates/status/666099513...  ...   None     None
# 2341  https://twitter.com/dog_rates/status/666094000...  ...   None     None
# 2342  https://twitter.com/dog_rates/status/666082916...  ...   None     None
# 2343  https://twitter.com/dog_rates/status/666073100...  ...   None     None
# 2344  https://twitter.com/dog_rates/status/666071193...  ...   None     None
# 2345  https://twitter.com/dog_rates/status/666063827...  ...   None     None
# 2346  https://twitter.com/dog_rates/status/666058600...  ...   None     None
# 2347  https://twitter.com/dog_rates/status/666057090...  ...   None     None
# 2348  https://twitter.com/dog_rates/status/666055525...  ...   None     None
# 2349  https://twitter.com/dog_rates/status/666051853...  ...   None     None
# 2350  https://twitter.com/dog_rates/status/666050758...  ...   None     None
# 2351  https://twitter.com/dog_rates/status/666049248...  ...   None     None
# 2352  https://twitter.com/dog_rates/status/666044226...  ...   None     None
# 2353  https://twitter.com/dog_rates/status/666033412...  ...   None     None
# 2354  https://twitter.com/dog_rates/status/666029285...  ...   None     None
# 2355  https://twitter.com/dog_rates/status/666020888...  ...   None     None
#
#       pupper  puppo                                         text_check  \
# 0       None   None  This is Phineas. He's a mystical boy. Only eve...
# 1       None   None  This is Tilly. She's just checking pup on you....
# 2       None   None  This is Archie. He is a rare Norwegian Pouncin...
# 3       None   None  This is Darla. She commenced a snooze mid meal...
# 4       None   None  This is Franklin. He would like you to stop ca...
# 5       None   None  Here we have a majestic great white breaching ...
# 6       None   None  Meet Jax. He enjoys ice cream so much he gets ...
# 7       None   None  When you watch your owner call another dog a g...
# 8       None   None  This is Zoey. She doesn't want to be one of th...
# 9       None   None  This is Cassie. She is a college pup. Studying...
# 10      None   None  This is Koda. He is a South Australian decksha...
# 11      None   None  This is Bruno. He is a service shark. Only get...
# 12      None  puppo  Here's a puppo that seems to be on the fence a...
# 13      None   None  This is Ted. He does his best. Sometimes that'...
# 14      None  puppo  This is Stuart. He's sporting his favorite fan...
# 15      None   None  This is Oliver. You're witnessing one of his m...
# 16      None   None  This is Jim. He found a fren. Taught him how t...
# 17      None   None  This is Zeke. He has a new stick. Very proud o...
# 18      None   None  This is Ralphus. He's powering up. Attempting ...
# 19      None   None                                                NaN
# 20      None   None  This is Gerald. He was just told he didn't get...
# 21      None   None  This is Jeffrey. He has a monopoly on the pool...
# 22      None   None  I've yet to rate a Venezuelan Hover Wiener. Th...
# 23      None   None  This is Canela. She attempted some fancy porch...
# 24      None   None  You may not have known you needed to see this ...
# 25      None   None  This... is a Jubilant Antarctic House Bear. We...
# 26      None   None  This is Maya. She's very shy. Rarely leaves he...
# 27      None   None  This is Mingus. He's a wonderful father to his...
# 28      None   None  This is Derek. He's late for a dog meeting. 13...
# 29    pupper   None  This is Roscoe. Another pupper fallen victim t...
# ...      ...    ...                                                ...
# 2326    None   None  This is quite the dog. Gets really excited whe...
# 2327    None   None  This is a southern Vesuvius bumblegruff. Can d...
# 2328    None   None  Oh goodness. A super rare northeast Qdoba kang...
# 2329    None   None  Those are sunglasses and a jean jacket. 11/10 ...
# 2330    None   None  Unique dog here. Very small. Lives in containe...
# 2331    None   None  Here we have a mixed Asiago from the Galápagos...
# 2332    None   None  Look at this jokester thinking seat belt laws ...
# 2333    None   None  This is an extremely rare horned Parthenon. No...
# 2334    None   None  This is a funny dog. Weird toes. Won't come do...
# 2335    None   None  This is an Albanian 3 1/2 legged  Episcopalian...
# 2336    None   None     Can take selfies 11/10 https://t.co/ws2AMaNwPW
# 2337    None   None  Very concerned about fellow dog trapped in com...
# 2338    None   None  Not familiar with this breed. No tail (weird)....
# 2339    None   None  Oh my. Here you are seeing an Adobe Setter giv...
# 2340    None   None  Can stand on stump for what seems like a while...
# 2341    None   None  This appears to be a Mongolian Presbyterian mi...
# 2342    None   None  Here we have a well-established sunblockerspan...
# 2343    None   None  Let's hope this flight isn't Malaysian (lol). ...
# 2344    None   None  Here we have a northern speckled Rhododendron....
# 2345    None   None  This is the happiest dog you will ever see. Ve...
# 2346    None   None  Here is the Rand Paul of retrievers folks! He'...
# 2347    None   None  My oh my. This is a rare blond Canadian terrie...
# 2348    None   None  Here is a Siberian heavily armored polar bear ...
# 2349    None   None  This is an odd dog. Hard on the outside but lo...
# 2350    None   None  This is a truly beautiful English Wilson Staff...
# 2351    None   None  Here we have a 1949 1st generation vulpix. Enj...
# 2352    None   None  This is a purebred Piers Morgan. Loves to Netf...
# 2353    None   None  Here is a very happy pup. Big fan of well-main...
# 2354    None   None  This is a western brown Mitsubishi terrier. Up...
# 2355    None   None  Here we have a Japanese Irish Setter. Lost eye...
#
#                                         dog_picture_url  \
# 0        http://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
# 1        http://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2        http://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 3        http://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 4        http://pbs.twimg.com/media/DF6hr6AVYAAZ8G8.jpg
# 5        http://pbs.twimg.com/media/DF3HwyEWsAABqE6.jpg
# 6        http://pbs.twimg.com/media/DF1eOmZXUAALUcq.jpg
# 7        http://pbs.twimg.com/media/DFyBag_UQAAhhBC.jpg
# 8        http://pbs.twimg.com/media/DFwUU__XcAEpyXI.jpg
# 9        http://pbs.twimg.com/media/DFrEyVuW0AAO3t9.jpg
# 10       http://pbs.twimg.com/media/DFnwSY4WAAAMliS.jpg
# 11       http://pbs.twimg.com/media/DFl99B1WsAITKsg.jpg
# 12       http://pbs.twimg.com/media/DFi579UWsAAatzw.jpg
# 13       http://pbs.twimg.com/media/DFihzFfXsAYGDPR.jpg
# 14       http://pbs.twimg.com/media/DFg_2PVW0AEHN3p.jpg
# 15    http://pbs.twimg.com/ext_tw_video_thumb/889278...
# 16       http://pbs.twimg.com/media/DFYRgsOUQAARGhO.jpg
# 17       http://pbs.twimg.com/media/DFWra-3VYAA2piG.jpg
# 18       http://pbs.twimg.com/media/DFTH_OiUMAE-k4M.jpg
# 19                                                  NaN
# 20       http://pbs.twimg.com/media/DFMWn56WsAAkA7B.jpg
# 21       http://pbs.twimg.com/media/DFHDQBbXgAEqY7t.jpg
# 22    http://pbs.twimg.com/ext_tw_video_thumb/887517...
# 23       http://pbs.twimg.com/media/DFDw2tsUAAEw7XW.jpg
# 24    http://pbs.twimg.com/ext_tw_video_thumb/887343...
# 25       http://pbs.twimg.com/media/DE-eAq6UwAA-jaE.jpg
# 26       http://pbs.twimg.com/media/DE8yicKXoAAnSF8.jpg
# 27       http://pbs.twimg.com/media/DE5Se8FXcAAJFx4.jpg
# 28       http://pbs.twimg.com/media/DE4fEDzWAAAyHMM.jpg
# 29       http://pbs.twimg.com/media/DE0BTnQUwAApKEH.jpg
# ...                                                 ...
# 2326     http://pbs.twimg.com/media/CT-RugiWIAELEaq.jpg
# 2327     http://pbs.twimg.com/media/CT-NvwmW4AAugGZ.jpg
# 2328     http://pbs.twimg.com/media/CT-D2ZHWIAA3gK1.jpg
# 2329     http://pbs.twimg.com/media/CT9vZEYWUAAlZ05.jpg
# 2330     http://pbs.twimg.com/media/CT9lXGsUcAAyUFt.jpg
# 2331     http://pbs.twimg.com/media/CT9cx0tUEAAhNN_.jpg
# 2332     http://pbs.twimg.com/media/CT9Vn7PWoAA_ZCM.jpg
# 2333     http://pbs.twimg.com/media/CT9OwFIWEAMuRje.jpg
# 2334     http://pbs.twimg.com/media/CT8mx7KW4AEQu8N.jpg
# 2335     http://pbs.twimg.com/media/CT8g3BpUEAAuFjg.jpg
# 2336     http://pbs.twimg.com/media/CT8T1mtUwAA3aqm.jpg
# 2337     http://pbs.twimg.com/media/CT8QCd1WEAADXws.jpg
# 2338     http://pbs.twimg.com/media/CT56LSZWoAAlJj2.jpg
# 2339     http://pbs.twimg.com/media/CT54YGiWUAEZnoK.jpg
# 2340     http://pbs.twimg.com/media/CT51-JJUEAA6hV8.jpg
# 2341     http://pbs.twimg.com/media/CT5w9gUW4AAsBNN.jpg
# 2342     http://pbs.twimg.com/media/CT5m4VGWEAAtKc8.jpg
# 2343     http://pbs.twimg.com/media/CT5d9DZXAAALcwe.jpg
# 2344     http://pbs.twimg.com/media/CT5cN_3WEAAlOoZ.jpg
# 2345     http://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# 2346     http://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 2347     http://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 2348     http://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 2349     http://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 2350     http://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 2351     http://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 2352     http://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 2353     http://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 2354     http://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2355     http://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
#
#                                           tweet_web_url favourite_count  \
# 0     https://twitter.com/dog_rates/status/892420643...         37434.0
# 1     https://twitter.com/dog_rates/status/892177421...         32164.0
# 2     https://twitter.com/dog_rates/status/891815181...         24251.0
# 3     https://twitter.com/dog_rates/status/891689557...         40731.0
# 4     https://twitter.com/dog_rates/status/891327558...         38968.0
# 5     https://twitter.com/dog_rates/status/891087950...         19575.0
# 6     https://twitter.com/dog_rates/status/890971913...         11437.0
# 7     https://twitter.com/dog_rates/status/890729181...         63112.0
# 8     https://twitter.com/dog_rates/status/890609185...         26940.0
# 9     https://twitter.com/dog_rates/status/890240255...         30873.0
# 10    https://twitter.com/dog_rates/status/890006608...         29685.0
# 11    https://twitter.com/dog_rates/status/889880896...         26938.0
# 12    https://twitter.com/dog_rates/status/889665388...         46509.0
# 13    https://twitter.com/dog_rates/status/889638837...         26212.0
# 14    https://twitter.com/dog_rates/status/889531135...         14628.0
# 15    https://twitter.com/dog_rates/status/889278841...         24423.0
# 16    https://twitter.com/dog_rates/status/888917238...         28166.0
# 17    https://twitter.com/dog_rates/status/888804989...         24745.0
# 18    https://twitter.com/dog_rates/status/888554962...         19173.0
# 19                                                  NaN             NaN
# 20    https://twitter.com/dog_rates/status/888078434...         21056.0
# 21    https://twitter.com/dog_rates/status/887705289...         29200.0
# 22    https://twitter.com/dog_rates/status/887517139...         44809.0
# 23    https://twitter.com/dog_rates/status/887473957...         66651.0
# 24    https://twitter.com/dog_rates/status/887343217...         32572.0
# 25    https://twitter.com/dog_rates/status/887101392...         29581.0
# 26    https://twitter.com/dog_rates/status/886983233...         33959.0
# 27    https://twitter.com/dog_rates/status/886736880...         11636.0
# 28    https://twitter.com/dog_rates/status/886680336...         21699.0
# 29    https://twitter.com/dog_rates/status/886366144...         20483.0
# ...                                                 ...             ...
# 2326  https://twitter.com/dog_rates/status/666411507...           427.0
# 2327  https://twitter.com/dog_rates/status/666407126...           103.0
# 2328  https://twitter.com/dog_rates/status/666396247...           161.0
# 2329  https://twitter.com/dog_rates/status/666373753...           179.0
# 2330  https://twitter.com/dog_rates/status/666362758...           753.0
# 2331  https://twitter.com/dog_rates/status/666353288...           211.0
# 2332  https://twitter.com/dog_rates/status/666345417...           282.0
# 2333  https://twitter.com/dog_rates/status/666337882...           190.0
# 2334  https://twitter.com/dog_rates/status/666293911...           484.0
# 2335  https://twitter.com/dog_rates/status/666287406...           141.0
# 2336  https://twitter.com/dog_rates/status/666273097...           167.0
# 2337  https://twitter.com/dog_rates/status/666268910...            99.0
# 2338  https://twitter.com/dog_rates/status/666104133...         13879.0
# 2339  https://twitter.com/dog_rates/status/666102155...            75.0
# 2340  https://twitter.com/dog_rates/status/666099513...           148.0
# 2341  https://twitter.com/dog_rates/status/666094000...           158.0
# 2342  https://twitter.com/dog_rates/status/666082916...           110.0
# 2343  https://twitter.com/dog_rates/status/666073100...           312.0
# 2344  https://twitter.com/dog_rates/status/666071193...           140.0
# 2345  https://twitter.com/dog_rates/status/666063827...           458.0
# 2346  https://twitter.com/dog_rates/status/666058600...           108.0
# 2347  https://twitter.com/dog_rates/status/666057090...           282.0
# 2348  https://twitter.com/dog_rates/status/666055525...           422.0
# 2349  https://twitter.com/dog_rates/status/666051853...          1184.0
# 2350  https://twitter.com/dog_rates/status/666050758...           129.0
# 2351  https://twitter.com/dog_rates/status/666049248...           103.0
# 2352  https://twitter.com/dog_rates/status/666044226...           287.0
# 2353  https://twitter.com/dog_rates/status/666033412...           120.0
# 2354  https://twitter.com/dog_rates/status/666029285...           124.0
# 2355  https://twitter.com/dog_rates/status/666020888...          2494.0
#
#      retweet_count retweet_status_id_api
# 0           8138.0                  None
# 1           6029.0                  None
# 2           3991.0                  None
# 3           8304.0                  None
# 4           8992.0                  None
# 5           2985.0                  None
# 6           1979.0                  None
# 7          18106.0                  None
# 8           4098.0                  None
# 9           7078.0                  None
# 10          7033.0                  None
# 11          4783.0                  None
# 12          9627.0                  None
# 13          4350.0                  None
# 14          2163.0                  None
# 15          5162.0                  None
# 16          4330.0                  None
# 17          4107.0                  None
# 18          3388.0                  None
# 19             NaN                   NaN
# 20          3342.0                  None
# 21          5165.0                  None
# 22         11232.0                  None
# 23         17422.0                  None
# 24         10014.0                  None
# 25          5723.0                  None
# 26          7433.0                  None
# 27          3130.0                  None
# 28          4282.0                  None
# 29          3071.0                  None
# ...            ...                   ...
# 2326         319.0                  None
# 2327          37.0                  None
# 2328          81.0                  None
# 2329          87.0                  None
# 2330         553.0                  None
# 2331          71.0                  None
# 2332         131.0                  None
# 2333          88.0                  None
# 2334         341.0                  None
# 2335          63.0                  None
# 2336          75.0                  None
# 2337          34.0                  None
# 2338        6289.0                  None
# 2339          11.0                  None
# 2340          64.0                  None
# 2341          70.0                  None
# 2342          43.0                  None
# 2343         157.0                  None
# 2344          56.0                  None
# 2345         211.0                  None
# 2346          56.0                  None
# 2347         136.0                  None
# 2348         232.0                  None
# 2349         823.0                  None
# 2350          56.0                  None
# 2351          41.0                  None
# 2352         135.0                  None
# 2353          43.0                  None
# 2354          46.0                  None
# 2355         493.0                  None
#
# [2356 rows x 23 columns]

# %%
tweet_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2356 entries, 0 to 2355
# Data columns (total 23 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# puppo                         2356 non-null object
# text_check                    2335 non-null object
# dog_picture_url               2335 non-null object
# tweet_web_url                 2335 non-null object
# favourite_count               2335 non-null float64
# retweet_count                 2335 non-null float64
# retweet_status_id_api         2335 non-null object
# dtypes: float64(6), int64(3), object(14)
# memory usage: 441.8+ KB

# %% [markdown]
# #### Dropping rows that have no favourite_rating and retween_count (this is because those tweets were deleted, and where subsequntly not received from Twitter API

# %%
tweet_clean = tweet_clean[tweet_clean.favourite_count.notnull()]

# %%
tweet_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2335 entries, 0 to 2355
# Data columns (total 23 columns):
# tweet_id                      2335 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2335 non-null object
# source                        2335 non-null object
# text                          2335 non-null object
# retweeted_status_id           165 non-null float64
# retweeted_status_user_id      165 non-null float64
# retweeted_status_timestamp    165 non-null object
# expanded_urls                 2276 non-null object
# rating_numerator              2335 non-null int64
# rating_denominator            2335 non-null int64
# name                          2335 non-null object
# doggo                         2335 non-null object
# floofer                       2335 non-null object
# pupper                        2335 non-null object
# puppo                         2335 non-null object
# text_check                    2335 non-null object
# dog_picture_url               2335 non-null object
# tweet_web_url                 2335 non-null object
# favourite_count               2335 non-null float64
# retweet_count                 2335 non-null float64
# retweet_status_id_api         2335 non-null object
# dtypes: float64(6), int64(3), object(14)
# memory usage: 437.8+ KB

# %%
tweet_clean.sample(5)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 701   786051337297522688           7.727430e+17         7.305050e+17
# 1471  693993230313091072                    NaN                  NaN
# 2350  666050758794694657                    NaN                  NaN
# 2193  668902994700836864                    NaN                  NaN
# 304   836380477523124226                    NaN                  NaN
#
#                       timestamp  \
# 701   2016-10-12 03:50:17 +0000
# 1471  2016-02-01 03:04:14 +0000
# 2350  2015-11-16 00:30:50 +0000
# 2193  2015-11-23 21:24:36 +0000
# 304   2017-02-28 01:00:19 +0000
#
#                                                  source  \
# 701   <a href="http://twitter.com/download/iphone" r...
# 1471  <a href="http://vine.co" rel="nofollow">Vine -...
# 2350  <a href="http://twitter.com/download/iphone" r...
# 2193  <a href="http://twitter.com/download/iphone" r...
# 304   <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 701             13/10 for breakdancing puppo @shibbnbot                  NaN
# 1471  These lil fellas are the best of friends. 12/1...                  NaN
# 2350  This is a truly beautiful English Wilson Staff...                  NaN
# 2193  Meet Lambeau. He's a Whistling Haiku from the ...                  NaN
# 304   This is Ava. She just blasted off. Streamline ...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 701                        NaN                        NaN
# 1471                       NaN                        NaN
# 2350                       NaN                        NaN
# 2193                       NaN                        NaN
# 304                        NaN                        NaN
#
#                                           expanded_urls  ...  doggo  floofer  \
# 701                                                 NaN  ...   None     None
# 1471                      https://vine.co/v/i5ETazP5hrm  ...   None     None
# 2350  https://twitter.com/dog_rates/status/666050758...  ...   None     None
# 2193  https://twitter.com/dog_rates/status/668902994...  ...   None     None
# 304   https://twitter.com/dog_rates/status/836380477...  ...   None     None
#
#       pupper  puppo                                         text_check  \
# 701     None  puppo            13/10 for breakdancing puppo @shibbnbot
# 1471    None   None  These lil fellas are the best of friends. 12/1...
# 2350    None   None  This is a truly beautiful English Wilson Staff...
# 2193    None   None  Meet Lambeau. He's a Whistling Haiku from the ...
# 304   pupper   None  This is Ava. She just blasted off. Streamline ...
#
#                                      dog_picture_url  \
# 701                                             None
# 1471                                            None
# 2350  http://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 2193  http://pbs.twimg.com/media/CUhruUgUAAAa8FQ.jpg
# 304   http://pbs.twimg.com/media/C5trm6iWgAQ22Hw.jpg
#
#                                           tweet_web_url favourite_count  \
# 701   https://twitter.com/dog_rates/status/830583320...          1505.0
# 1471  https://twitter.com/dog_rates/status/830583320...          1927.0
# 2350  https://twitter.com/dog_rates/status/666050758...           129.0
# 2193  https://twitter.com/dog_rates/status/668902994...           317.0
# 304   https://twitter.com/dog_rates/status/836380477...         15244.0
#
#      retweet_count retweet_status_id_api
# 701          165.0                  None
# 1471         423.0                  None
# 2350          56.0                  None
# 2193         102.0                  None
# 304         3127.0                  None
#
# [5 rows x 23 columns]

# %%
#few checks to see values are sensible
tweet_clean.favourite_count.sort_values().head(5)
# Out:
# 1295    51.0
# 342     68.0
# 2339    75.0
# 2298    82.0
# 2319    99.0
# Name: favourite_count, dtype: float64

# %%
tweet_clean.favourite_count.sort_values().tail(5)
# Out:
# 1079    119452.0
# 135     120097.0
# 534     124911.0
# 413     137875.0
# 1039    161664.0
# Name: favourite_count, dtype: float64

# %%
tweet_clean.retweet_count.sort_values().head(5)
# Out:
# 291     1.0
# 342     2.0
# 1295    2.0
# 274     2.0
# 113     3.0
# Name: retweet_count, dtype: float64

# %%
tweet_clean.retweet_count.sort_values().tail(5)
# Out:
# 66      42651.0
# 413     46757.0
# 534     59854.0
# 1079    60745.0
# 1039    82098.0
# Name: retweet_count, dtype: float64

# %% [markdown]
# #### Checking tweet text is correct for each tweet (comparing two columns that store tweet text, deciding which to keep)

# %%
sum(tweet_clean.text != tweet_clean.text_check)
# Out:
# 0

# %% [markdown]
# Ok, marvelous, all text from tweets was downloaded correctly;
# therefore can just drop one of the text columns, will drop `text_check`

# %%
tweet_clean.drop(columns=['text_check'], axis=1, inplace=True)
# Out:
# C:\Users\vilij\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
tweet_clean.head(2)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
#
#                                        expanded_urls  ...     name  doggo  \
# 0  https://twitter.com/dog_rates/status/892420643...  ...  Phineas   None
# 1  https://twitter.com/dog_rates/status/892177421...  ...    Tilly   None
#
#   floofer pupper puppo                                 dog_picture_url  \
# 0    None   None  None  http://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
# 1    None   None  None  http://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
#
#                                        tweet_web_url favourite_count  \
# 0  https://twitter.com/dog_rates/status/892420643...         37434.0
# 1  https://twitter.com/dog_rates/status/892177421...         32164.0
#
#   retweet_count  retweet_status_id_api
# 0        8138.0                   None
# 1        6029.0                   None
#
# [2 rows x 22 columns]

# %% [markdown]
# #### Similarly checking other potentially duplicated columns, including tweet_url (columns `expanded_urls` and `tweet_web_url`) and retweet_id (columns `retweeted_status_id` and  `retween_status_id_api`)

# %%
sum(tweet_clean.expanded_urls != tweet_clean.tweet_web_url)
# Out:
# 852

# %% [markdown]
# Hm, not such a great match..

# %%
tweet_clean[tweet_clean.expanded_urls != tweet_clean.tweet_web_url][['expanded_urls','tweet_web_url']]
# Out:
#                                           expanded_urls  \
# 4     https://twitter.com/dog_rates/status/891327558...
# 6     https://gofundme.com/ydvmve-surgery-for-jax,ht...
# 7     https://twitter.com/dog_rates/status/890729181...
# 10    https://twitter.com/dog_rates/status/890006608...
# 13    https://twitter.com/dog_rates/status/889638837...
# 17    https://twitter.com/dog_rates/status/888804989...
# 18    https://twitter.com/dog_rates/status/888554962...
# 20    https://twitter.com/dog_rates/status/888078434...
# 23    https://twitter.com/dog_rates/status/887473957...
# 26    https://twitter.com/dog_rates/status/886983233...
# 27    https://www.gofundme.com/mingusneedsus,https:/...
# 29    https://twitter.com/dog_rates/status/886366144...
# 30                                                  NaN
# 32    https://twitter.com/dog_rates/status/886053434...
# 35    https://twitter.com/4bonds2carbon/status/88551...
# 36    https://twitter.com/dog_rates/status/830583320...
# 37    https://twitter.com/dog_rates/status/885167619...
# 39    https://twitter.com/dog_rates/status/884876753...
# 42    https://twitter.com/kaijohnson_19/status/88396...
# 45    https://twitter.com/dog_rates/status/883482846...
# 47    https://twitter.com/dog_rates/status/883117836...
# 48    https://twitter.com/dog_rates/status/882992080...
# 51    https://twitter.com/dog_rates/status/882268110...
# 52    https://twitter.com/dog_rates/status/882045870...
# 55                                                  NaN
# 60    https://twitter.com/dog_rates/status/880465832...
# 61    https://twitter.com/dog_rates/status/880221127...
# 63    https://twitter.com/dog_rates/status/879862464...
# 64                                                  NaN
# 68    https://twitter.com/dog_rates/status/878057613...
# ...                                                 ...
# 1906  https://twitter.com/dog_rates/status/674468880...
# 1914                                                NaN
# 1916                      https://vine.co/v/i7nWzrenw5h
# 1939  https://twitter.com/dog_rates/status/673887867...
# 1940                                                NaN
# 1945  https://twitter.com/dog_rates/status/673707060...
# 1948  https://twitter.com/dog_rates/status/673697980...
# 1949  https://twitter.com/dog_rates/status/673689733...
# 1962  https://twitter.com/dog_rates/status/673355879...
# 1968  https://twitter.com/dog_rates/status/673320132...
# 1969  https://twitter.com/dog_rates/status/673317986...
# 2005  https://twitter.com/dog_rates/status/672272411...
# 2027  https://twitter.com/dog_rates/status/671874878...
# 2031  https://twitter.com/dog_rates/status/671768281...
# 2035  https://twitter.com/dog_rates/status/671735591...
# 2038                                                NaN
# 2039  https://twitter.com/dog_rates/status/671547767...
# 2049  https://twitter.com/dog_rates/status/671504605...
# 2056  https://twitter.com/dog_rates/status/671357843...
# 2058  https://twitter.com/dog_rates/status/671347597...
# 2073  https://twitter.com/dog_rates/status/670995969...
# 2084  https://twitter.com/dog_rates/status/670807719...
# 2149                                                NaN
# 2189                                                NaN
# 2205  https://twitter.com/dog_rates/status/668633411...
# 2209  https://twitter.com/dog_rates/status/668623201...
# 2212                      https://vine.co/v/ea0OwvPTx9l
# 2259  https://twitter.com/dogratingrating/status/667...
# 2260  https://twitter.com/dogratingrating/status/667...
# 2298                                                NaN
#
#                                           tweet_web_url
# 4     https://twitter.com/dog_rates/status/891327558...
# 6     https://twitter.com/dog_rates/status/890971913...
# 7     https://twitter.com/dog_rates/status/890729181...
# 10    https://twitter.com/dog_rates/status/890006608...
# 13    https://twitter.com/dog_rates/status/889638837...
# 17    https://twitter.com/dog_rates/status/888804989...
# 18    https://twitter.com/dog_rates/status/888554962...
# 20    https://twitter.com/dog_rates/status/888078434...
# 23    https://twitter.com/dog_rates/status/887473957...
# 26    https://twitter.com/dog_rates/status/886983233...
# 27    https://twitter.com/dog_rates/status/886736880...
# 29    https://twitter.com/dog_rates/status/886366144...
# 30    https://twitter.com/dog_rates/status/830583320...
# 32    https://twitter.com/dog_rates/status/830583320...
# 35    https://twitter.com/dog_rates/status/830583320...
# 36    https://twitter.com/dog_rates/status/830583320...
# 37    https://twitter.com/dog_rates/status/885167619...
# 39    https://twitter.com/dog_rates/status/884876753...
# 42    https://twitter.com/dog_rates/status/830583320...
# 45    https://twitter.com/dog_rates/status/883482846...
# 47    https://twitter.com/dog_rates/status/883117836...
# 48    https://twitter.com/dog_rates/status/882992080...
# 51    https://twitter.com/dog_rates/status/882268110...
# 52    https://twitter.com/dog_rates/status/882045870...
# 55    https://twitter.com/dog_rates/status/830583320...
# 60    https://twitter.com/dog_rates/status/880465832...
# 61    https://twitter.com/dog_rates/status/880221127...
# 63    https://twitter.com/dog_rates/status/879862464...
# 64    https://twitter.com/dog_rates/status/830583320...
# 68    https://twitter.com/dog_rates/status/830583320...
# ...                                                 ...
# 1906  https://twitter.com/dog_rates/status/674468880...
# 1914  https://twitter.com/dog_rates/status/830583320...
# 1916  https://twitter.com/dog_rates/status/830583320...
# 1939  https://twitter.com/dog_rates/status/673887867...
# 1940  https://twitter.com/dog_rates/status/830583320...
# 1945  https://twitter.com/dog_rates/status/673707060...
# 1948  https://twitter.com/dog_rates/status/673697980...
# 1949  https://twitter.com/dog_rates/status/673689733...
# 1962  https://twitter.com/dog_rates/status/673355879...
# 1968  https://twitter.com/dog_rates/status/673320132...
# 1969  https://twitter.com/dog_rates/status/673317986...
# 2005  https://twitter.com/dog_rates/status/672272411...
# 2027  https://twitter.com/dog_rates/status/671874878...
# 2031  https://twitter.com/dog_rates/status/671768281...
# 2035  https://twitter.com/dog_rates/status/671735591...
# 2038  https://twitter.com/dog_rates/status/830583320...
# 2039  https://twitter.com/dog_rates/status/671547767...
# 2049  https://twitter.com/dog_rates/status/671504605...
# 2056  https://twitter.com/dog_rates/status/671357843...
# 2058  https://twitter.com/dog_rates/status/671347597...
# 2073  https://twitter.com/dog_rates/status/670995969...
# 2084  https://twitter.com/dog_rates/status/670807719...
# 2149  https://twitter.com/dog_rates/status/830583320...
# 2189  https://twitter.com/dog_rates/status/830583320...
# 2205  https://twitter.com/dog_rates/status/668633411...
# 2209  https://twitter.com/dog_rates/status/668623201...
# 2212  https://twitter.com/dog_rates/status/830583320...
# 2259  https://twitter.com/dogratingrating/status/667...
# 2260  https://twitter.com/dogratingrating/status/667...
# 2298  https://twitter.com/dog_rates/status/830583320...
#
# [852 rows x 2 columns]

# %%
tweet_clean[tweet_clean.expanded_urls != tweet_clean.tweet_web_url].loc[2209,['expanded_urls','tweet_web_url']].values
# Out:
# array(['https://twitter.com/dog_rates/status/668623201287675904/photo/1,https://twitter.com/dog_rates/status/668623201287675904/photo/1,https://twitter.com/dog_rates/status/668623201287675904/photo/1,https://twitter.com/dog_rates/status/668623201287675904/photo/1',
#        'https://twitter.com/dog_rates/status/668623201287675904/photo/1'],
#       dtype=object)

# %% [markdown]
# Ok, seems that `tweet_web_url` is more complete and also devoid of repetitions/multiple entries (unlike `expanded_urls` column); threrefore will drop `expanded_urls` column

# %%
tweet_clean.drop(columns=['expanded_urls'], axis=1, inplace=True)
# Out:
# C:\Users\vilij\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
tweet_clean.head(2)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  rating_numerator  ...  \
# 0                       NaN                        NaN                13  ...
# 1                       NaN                        NaN                13  ...
#
#       name doggo floofer pupper puppo  \
# 0  Phineas  None    None   None  None
# 1    Tilly  None    None   None  None
#
#                                   dog_picture_url  \
# 0  http://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
# 1  http://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
#
#                                        tweet_web_url favourite_count  \
# 0  https://twitter.com/dog_rates/status/892420643...         37434.0
# 1  https://twitter.com/dog_rates/status/892177421...         32164.0
#
#    retweet_count  retweet_status_id_api
# 0         8138.0                   None
# 1         6029.0                   None
#
# [2 rows x 21 columns]

# %% [markdown]
# #### Now checking for duplications in retweet_id (columns `retweeted_status_id` and  `retween_status_id_api`)

# %%
#normalising for NaN and 'None'
tweet_clean.retweet_status_id_api[tweet_clean.retweet_status_id_api == 'None'] = np.nan
# Out:
# C:\Users\vilij\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\vilij\Anaconda3\lib\site-packages\pandas\core\generic.py:8682: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\vilij\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2910: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
sum(tweet_clean.retweet_status_id_api == 'None')
# Out:
# 0

# %%
sum(tweet_clean.retweet_status_id_api.isnull())
# Out:
# 2170

# %%
#Ok, now let's compare the two columns
tweet_clean[tweet_clean.retweeted_status_id != tweet_clean.retweet_status_id_api][['retweeted_status_id','retweet_status_id_api']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2335 entries, 0 to 2355
# Data columns (total 2 columns):
# retweeted_status_id      165 non-null float64
# retweet_status_id_api    165 non-null object
# dtypes: float64(1), object(1)
# memory usage: 54.7+ KB

# %%
#ok, for comparison let's try to use `retweet_status_id_api` values as float (also NaNs are accomodated for that way)
sum(tweet_clean.retweeted_status_id == tweet_clean.retweet_status_id_api.astype(float))
# Out:
# 165

# %%
temp = tweet_clean.retweet_status_id_api.astype(float)
temp2 = tweet_clean.retweeted_status_id
sum(temp[temp.notnull()] != temp2[temp2.notnull()])
# Out:
# 0

# %% [markdown]
# #### Ok, so in conclusion, the `retweeted_status_id`  and `retweet_status_id_api` are the same; therefore I will drop the `retweet_status_id_api` column

# %%
tweet_clean.drop(columns=['retweet_status_id_api'], axis=1, inplace=True)
# Out:
# C:\Users\vilij\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
tweet_clean.head(3)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  rating_numerator  \
# 0                       NaN                        NaN                13
# 1                       NaN                        NaN                13
# 2                       NaN                        NaN                12
#
#    rating_denominator     name doggo floofer pupper puppo  \
# 0                  10  Phineas  None    None   None  None
# 1                  10    Tilly  None    None   None  None
# 2                  10   Archie  None    None   None  None
#
#                                   dog_picture_url  \
# 0  http://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
# 1  http://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2  http://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
#
#                                        tweet_web_url  favourite_count  \
# 0  https://twitter.com/dog_rates/status/892420643...          37434.0
# 1  https://twitter.com/dog_rates/status/892177421...          32164.0
# 2  https://twitter.com/dog_rates/status/891815181...          24251.0
#
#    retweet_count
# 0         8138.0
# 1         6029.0
# 2         3991.0

# %% [markdown]
# #### For completeness with the `retweeted_status_id` column, will also convert it to integer (np.int64), in line with tweet_id
# To deal with NaNs I will first convert all NaNs to 0s, then the column to int64

# %%
tweet_clean.retweeted_status_id[tweet_clean.retweeted_status_id.isnull()] = 0
tweet_clean.retweeted_status_id = tweet_clean.retweeted_status_id.astype(np.int64)
#tweet_clean.retweeted_status_id[tweet_clean.retweeted_status_id == 0] = np.nan
# Out:
# C:\Users\vilij\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\vilij\Anaconda3\lib\site-packages\pandas\core\generic.py:8682: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\vilij\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2910: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\vilij\Anaconda3\lib\site-packages\pandas\core\generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
tweet_clean.retweeted_status_id.dtype
# Out:
# dtype('int64')

# %% [markdown]
# #### Checking ratings are correctly imported to ratings columns (from tweet text)

# %%
tweet_clean.loc[0].text
# Out:
# "This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10 https://t.co/MgUWQ76dJU"

# %%
test = tweet_clean.text.str.extract(r'(\d{1,4}[\.]?[\d{1,2}]?)([\s]?[/][\s]?)(\d{2,4})',expand = True)
test
# Out:
#        0  1   2
# 0     13  /  10
# 1     13  /  10
# 2     12  /  10
# 3     13  /  10
# 4     12  /  10
# 5     13  /  10
# 6     13  /  10
# 7     13  /  10
# 8     13  /  10
# 9     14  /  10
# 10    13  /  10
# 11    13  /  10
# 12    13  /  10
# 13    12  /  10
# 14    13  /  10
# 15    13  /  10
# 16    12  /  10
# 17    13  /  10
# 18    13  /  10
# 20    12  /  10
# 21    13  /  10
# 22    14  /  10
# 23    13  /  10
# 24    13  /  10
# 25    12  /  10
# 26    13  /  10
# 27    13  /  10
# 28    13  /  10
# 29    12  /  10
# 30    12  /  10
# ...   .. ..  ..
# 2326   2  /  10
# 2327   7  /  10
# 2328   9  /  10
# 2329  11  /  10
# 2330   6  /  10
# 2331   8  /  10
# 2332  10  /  10
# 2333   9  /  10
# 2334   3  /  10
# 2335   9  /  10
# 2336  11  /  10
# 2337  10  /  10
# 2338   1  /  10
# 2339  11  /  10
# 2340   8  /  10
# 2341   9  /  10
# 2342   6  /  10
# 2343  10  /  10
# 2344   9  /  10
# 2345  10  /  10
# 2346   8  /  10
# 2347   9  /  10
# 2348  10  /  10
# 2349   2  /  10
# 2350  10  /  10
# 2351   5  /  10
# 2352   6  /  10
# 2353   9  /  10
# 2354   7  /  10
# 2355   8  /  10
#
# [2335 rows x 3 columns]

# %%
sum(test[0].isnull())
# Out:
# 1

# %%
#let's check where NaNs are coming from
test = test.join(tweet_clean['text'], how='left')
test.to_csv('test.csv')

# %%
tweet_clean.rating_numerator.value_counts()
# Out:
# 12      554
# 11      464
# 10      459
# 13      340
# 9       157
# 8       102
# 7        55
# 14       51
# 5        37
# 6        32
# 3        19
# 4        17
# 1         9
# 2         9
# 420       2
# 0         2
# 15        2
# 75        2
# 80        1
# 20        1
# 24        1
# 26        1
# 44        1
# 50        1
# 60        1
# 165       1
# 84        1
# 88        1
# 144       1
# 182       1
# 143       1
# 666       1
# 960       1
# 1776      1
# 17        1
# 27        1
# 45        1
# 99        1
# 121       1
# 204       1
# Name: rating_numerator, dtype: int64

# %%
test[0].value_counts()
# Out:
# 12      554
# 11      464
# 10      459
# 13      340
# 9       158
# 8       102
# 7        54
# 14       51
# 5        35
# 6        32
# 3        19
# 4        17
# 2         9
# 1         8
# 0         2
# 15        2
# 420       2
# 75        2
# 9.5       1
# 80        1
# 007       1
# 44        1
# 144       1
# 27        1
# 960       1
# 666       1
# 17        1
# 121       1
# 88        1
# 1776      1
# 26        1
# 60        1
# 13.5      1
# 99        1
# 50        1
# 45        1
# 165       1
# 143       1
# 20        1
# 182       1
# 84        1
# 204       1
# Name: 0, dtype: int64

# %%
tweet_clean.rating_denominator.value_counts()
# Out:
# 10     2313
# 50        3
# 80        2
# 11        2
# 20        2
# 2         1
# 16        1
# 40        1
# 70        1
# 15        1
# 90        1
# 110       1
# 120       1
# 130       1
# 150       1
# 170       1
# 7         1
# 0         1
# Name: rating_denominator, dtype: int64

# %%
test[2].value_counts()
# Out:
# 10     2314
# 50        3
# 11        2
# 20        2
# 80        2
# 120       1
# 16        1
# 170       1
# 130       1
# 90        1
# 150       1
# 40        1
# 70        1
# 15        1
# 00        1
# 110       1
# Name: 2, dtype: int64

# %% [markdown]
# #### Overall quality of extratction looks good (check in CSV for exceptions, because it's much easier to see full text there);
# It seems that the really high values in denominator and occosationally numerator eg 1776 or 960 are actually valid ratings, and may be in some cases ratings of multiple of dogs in one picture.  Evcen 0 in denominator is a valid number, which was given twice, what it seems not to dogs but to random picture sent to @dog_rates. One real exception was that code reads 9.75 as 75.
# For now, will not delete any extreme values, because they're valid, will deal with these in visuals/analysis as relevant.

# %% [markdown]
# #### Therefore will now attach new ratings to `tweet_clean` dataframe, to carry out comparison between existings ratings there and newly extracted ratings, and to drop or keep columns accordingly.

# %%
test.columns
# Out:
# Index([0, 1, 2, 'text'], dtype='object')

# %%
tweet_clean.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'rating_numerator', 'rating_denominator',
#        'name', 'doggo', 'floofer', 'pupper', 'puppo', 'dog_picture_url',
#        'tweet_web_url', 'favourite_count', 'retweet_count'],
#       dtype='object')

# %%
#drop uncenessary columns from test dataframe
test.drop(columns=[1,'text'], axis = 1, inplace=True)

#rename columns
test.rename(columns={0:'rating_numerator_alt',2:'rating_denominator_alt'}, inplace=True)

#join test to tweet_clean
tweet_clean = tweet_clean.join(test, how='left')

# %%
tweet_clean.head(2)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                    0
# 1  This is Tilly. She's just checking pup on you....                    0
#
#    retweeted_status_user_id retweeted_status_timestamp  rating_numerator  ...  \
# 0                       NaN                        NaN                13  ...
# 1                       NaN                        NaN                13  ...
#
#    doggo floofer pupper puppo                                 dog_picture_url  \
# 0   None    None   None  None  http://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
# 1   None    None   None  None  http://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
#
#                                        tweet_web_url favourite_count  \
# 0  https://twitter.com/dog_rates/status/892420643...         37434.0
# 1  https://twitter.com/dog_rates/status/892177421...         32164.0
#
#   retweet_count  rating_numerator_alt  rating_denominator_alt
# 0        8138.0                    13                      10
# 1        6029.0                    13                      10
#
# [2 rows x 22 columns]

# %%
tweet_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2335 entries, 0 to 2355
# Data columns (total 22 columns):
# tweet_id                      2335 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2335 non-null object
# source                        2335 non-null object
# text                          2335 non-null object
# retweeted_status_id           2335 non-null int64
# retweeted_status_user_id      165 non-null float64
# retweeted_status_timestamp    165 non-null object
# rating_numerator              2335 non-null int64
# rating_denominator            2335 non-null int64
# name                          2335 non-null object
# doggo                         2335 non-null object
# floofer                       2335 non-null object
# pupper                        2335 non-null object
# puppo                         2335 non-null object
# dog_picture_url               2335 non-null object
# tweet_web_url                 2335 non-null object
# favourite_count               2335 non-null float64
# retweet_count                 2335 non-null float64
# rating_numerator_alt          2334 non-null object
# rating_denominator_alt        2334 non-null object
# dtypes: float64(5), int64(4), object(13)
# memory usage: 499.6+ KB

# %% [markdown]
# #### In order to do the comparison between existing ratings numerator and denominator columns (`rating_numerator` and `rating_denominator`) and newly extracted ones, we will need to convert both to float -- there were some ratings (e.g. 13.5/10) that were not intergers, so I decided to follow this rule

# %%
sum(tweet_clean.rating_numerator.astype(float) != tweet_clean.rating_numerator_alt.astype(float))
# Out:
# 4

# %%
print(tweet_clean[tweet_clean.rating_numerator.astype(float) != tweet_clean.rating_numerator_alt.astype(float)]['text'].values)
# Out:
# ['This is Bella. She hopes her smile made you smile. If not, she is also offering you her favorite monkey. 13.5/10 https://t.co/qjrljjt948'
#  'Meet Sam. She smiles 24/7 &amp; secretly aspires to be a reindeer. \nKeep Sam smiling by clicking and sharing this link:\nhttps://t.co/98tB8y7y7t https://t.co/LouL5vdvxx'
#  "I've been told there's a slight possibility he's checking his mirror. We'll bump to 9.5/10. Still a menace"
#  'This is an Albanian 3 1/2 legged  Episcopalian. Loves well-polished hardwood flooring. Penis on the collar. 9/10 https://t.co/d9NcXFKwLv']

# %%
tweet_clean[tweet_clean.rating_numerator.astype(float) != tweet_clean.rating_numerator_alt.astype(float)][['rating_numerator','rating_numerator_alt']]
# Out:
#       rating_numerator rating_numerator_alt
# 45                   5                 13.5
# 516                 24                  NaN
# 1689                 5                  9.5
# 2335                 1                    9

# %% [markdown]
# #### Conclusion:
# Newly extraceted ratings numerators (in column `rating_numerator_alt`) are the accurate ones for these 4 instances of mismatch

# %%
sum(tweet_clean.rating_denominator.astype(float) != tweet_clean.rating_denominator_alt.astype(float))
# Out:
# 2

# %%
print(tweet_clean[tweet_clean.rating_denominator.astype(float) != tweet_clean.rating_denominator_alt.astype(float)]['text'].values)
# Out:
# ['Meet Sam. She smiles 24/7 &amp; secretly aspires to be a reindeer. \nKeep Sam smiling by clicking and sharing this link:\nhttps://t.co/98tB8y7y7t https://t.co/LouL5vdvxx'
#  'This is an Albanian 3 1/2 legged  Episcopalian. Loves well-polished hardwood flooring. Penis on the collar. 9/10 https://t.co/d9NcXFKwLv']

# %%
tweet_clean[tweet_clean.rating_denominator.astype(float) != tweet_clean.rating_denominator_alt.astype(float)][['rating_denominator','rating_denominator_alt']]
# Out:
#       rating_denominator rating_denominator_alt
# 516                    7                    NaN
# 2335                   2                     10

# %% [markdown]
# #### Conclusion:
# Newly extraceted ratings denominators (in column `rating_denominator_alt`) are the accurate ones for these 2 instances of mismatch

# %% [markdown]
# #### ACTION:
# Drop existing ratings columns and replace them with newly extracted ratings columns.

# %%
tweet_clean.drop(columns=['rating_numerator','rating_denominator'], axis=1, inplace=True)
tweet_clean.rename(columns={'rating_numerator_alt':'rating_numerator','rating_denominator_alt':'rating_denominator'}, inplace=True)

# %%
tweet_clean.head(2)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                    0
# 1  This is Tilly. She's just checking pup on you....                    0
#
#    retweeted_status_user_id retweeted_status_timestamp     name doggo floofer  \
# 0                       NaN                        NaN  Phineas  None    None
# 1                       NaN                        NaN    Tilly  None    None
#
#   pupper puppo                                 dog_picture_url  \
# 0   None  None  http://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
# 1   None  None  http://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
#
#                                        tweet_web_url  favourite_count  \
# 0  https://twitter.com/dog_rates/status/892420643...          37434.0
# 1  https://twitter.com/dog_rates/status/892177421...          32164.0
#
#    retweet_count rating_numerator rating_denominator
# 0         8138.0               13                 10
# 1         6029.0               13                 10

# %% [markdown]
# #### Will also fix the two numerator values that were 75 instead of actual 9.5, and convert all values to Float type, to complete cleaning of this column

# %%
print(tweet_clean[tweet_clean.rating_numerator.astype(float) == 75][['text','rating_numerator']].values)
# Out:
# [["RT @dog_rates: This is Logan, the Chow who lived. He solemnly swears he's up to lots of good. H*ckin magical af 9.75/10 https://t.co/yBO5wu…"
#   '75']
#  ["This is Logan, the Chow who lived. He solemnly swears he's up to lots of good. H*ckin magical af 9.75/10 https://t.co/yBO5wuqaPS"
#   '75']]

# %%
tweet_clean.loc[tweet_clean.rating_numerator.astype(float) == 75,'rating_numerator'] = 9.75

# %%
tweet_clean.loc[tweet_clean.rating_numerator.astype(float) == 75,'rating_numerator']
# Out:
# Series([], Name: rating_numerator, dtype: object)

# %%
tweet_clean.rating_numerator = tweet_clean.rating_numerator.astype(float)

# %%
tweet_clean.rating_denominator = tweet_clean.rating_denominator.astype(float)

# %% [markdown]
# #### Will now proceed to check if 'dog stages' were correctly extracted, steps will include:
# * Creating one column for 'dog_stages' (from the four "dummy" columns of `doggo`, `floofer`, `pupper`, `puppo`)
# * Extracting 'dog stages' anew
# * Comparing to existing 'dog stages'
# * Identifying and keeping accurate column, dropping inaccurate column

# %%
tweet_clean.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'name', 'doggo', 'floofer', 'pupper',
#        'puppo', 'dog_picture_url', 'tweet_web_url', 'favourite_count',
#        'retweet_count', 'rating_numerator', 'rating_denominator'],
#       dtype='object')

# %%
tweet_clean.loc[tweet_clean.puppo == 'None','puppo'] = ''
tweet_clean.loc[tweet_clean.doggo == 'None','doggo'] = ''
tweet_clean.loc[tweet_clean.floofer == 'None','floofer'] = ''
tweet_clean.loc[tweet_clean.pupper == 'None','pupper'] = ''

# %%
#checking the possible outcome of concatenation
(tweet_clean.puppo+tweet_clean.doggo+tweet_clean.floofer+tweet_clean.pupper).value_counts()
# Out:
#                 1959
# pupper           244
# doggo             80
# puppo             29
# doggopupper       12
# floofer            9
# puppodoggo         1
# doggofloofer       1
# dtype: int64

# %% [markdown]
# Ok, looks like the given extraction was not too accurate, but the concatenation did work, so proceeding..

# %%
tweet_clean['dog_stages'] = tweet_clean.puppo+tweet_clean.doggo+tweet_clean.floofer+tweet_clean.pupper

# %%
#Quick sample check
tweet_clean.sample().values
# Out:
# array([[681981167097122816, nan, nan, '2015-12-29 23:32:35 +0000',
#         '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#         "This is Jimothy. He's a Trinidad Poliwhirl. Father was a velociraptor. Exceptionally unamused. 12/10 would adopt https://t.co/VwdIk0OwVx",
#         0, nan, nan, 'Jimothy', '', '', '', '',
#         'http://pbs.twimg.com/media/CXbiQHmWcAAt6Lm.jpg',
#         'https://twitter.com/dog_rates/status/681981167097122816/photo/1',
#         2886.0, 1085.0, 12.0, 10.0, '']], dtype=object)

# %%
#Checking out "floofer" class which is actually not defined, but will include it as separate from 'floof' and see what happens
tweet_clean[tweet_clean.floofer != ''].sample().values
# Out:
# array([[776218204058357768, nan, nan, '2016-09-15 00:36:55 +0000',
#         '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#         "Atlas rolled around in some chalk and now he's a magical rainbow floofer. 13/10 please never take a bath https://t.co/nzqTNw0744",
#         0, nan, nan, 'None', '', 'floofer', '', '',
#         'http://pbs.twimg.com/media/CsWuVEdWcAAqbe9.jpg',
#         'https://twitter.com/dog_rates/status/776218204058357768/photo/1',
#         31404.0, 17075.0, 13.0, 10.0, 'floofer']], dtype=object)

# %%
#extract anew
dog_stages_full = ['doggo', 'pupper','puppo','blep','snoot','floof','floofer']
test = tweet_clean.text.str.extract(r'([Pp]uppo|[Dd]oggo|[Pp]upper|[Bb]lep|[Ss]noot|[Ff]loofer|[Ff]loof)', expand =True)
test[0].value_counts()
# Out:
# pupper     262
# doggo       88
# puppo       37
# floof       20
# Floof       10
# Pupper       8
# Doggo        8
# Floofer      5
# floofer      3
# Blep         2
# Puppo        1
# blep         1
# Name: 0, dtype: int64

# %%
#attach new values, lowercase them
test[0] = test[0].str.lower()
test.rename(columns={0:'dog_stages_alt'}, inplace=True)
tweet_clean = tweet_clean.join(test, how='left')

# %%
#Quick sample check
tweet_clean[tweet_clean.dog_stages_alt.notnull()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 9     890240255349198849                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# 14    889531135344209921                    NaN                  NaN
# 25    887101392804085760                    NaN                  NaN
# 29    886366144734445568                    NaN                  NaN
# 43    884162670584377345                    NaN                  NaN
# 46    883360690899218434                    NaN                  NaN
# 49    882762694511734784                    NaN                  NaN
# 53    881906580714921986                    NaN                  NaN
# 54    881666595344535552                    NaN                  NaN
# 56    881536004380872706                    NaN                  NaN
# 61    880221127280381952                    NaN                  NaN
# 71    878776093423087618                    NaN                  NaN
# 78    877611172832227328                    NaN                  NaN
# 82    876838120628539392                    NaN                  NaN
# 83    876537666061221889                    NaN                  NaN
# 85    876120275196170240                    NaN                  NaN
# 92    874296783580663808                    NaN                  NaN
# 94    874012996292530176                    NaN                  NaN
# 97    873337748698140672                    NaN                  NaN
# 98    873213775632977920                    NaN                  NaN
# 99    872967104147763200                    NaN                  NaN
# 106   871879754684805121                    NaN                  NaN
# 107   871762521631449091                    NaN                  NaN
# 108   871515927908634625                    NaN                  NaN
# 110   871102520638267392                    NaN                  NaN
# 121   869596645499047938                    NaN                  NaN
# 129   867421006826221569                    NaN                  NaN
# 134   866686824827068416                    NaN                  NaN
# 135   866450705531457537                    NaN                  NaN
# ...                  ...                    ...                  ...
# 1897  674737130913071104                    NaN                  NaN
# 1900  674664755118911488                    NaN                  NaN
# 1903  674638615994089473                    NaN                  NaN
# 1907  674447403907457024                    NaN                  NaN
# 1915  674318007229923329                    NaN                  NaN
# 1921  674262580978937856                    NaN                  NaN
# 1928  674045139690631169                    NaN                  NaN
# 1930  674038233588723717                    NaN                  NaN
# 1936  673956914389192708                    NaN                  NaN
# 1937  673919437611909120                    NaN                  NaN
# 1945  673707060090052608                    NaN                  NaN
# 1948  673697980713705472                    NaN                  NaN
# 1954  673656262056419329                    NaN                  NaN
# 1956  673612854080196609                    NaN                  NaN
# 1960  673363615379013632                    NaN                  NaN
# 1967  673342308415348736                    NaN                  NaN
# 1970  673295268553605120                    NaN                  NaN
# 1974  673148804208660480                    NaN                  NaN
# 1977  672988786805112832                    NaN                  NaN
# 1980  672975131468300288                    NaN                  NaN
# 1981  672970152493887488                    NaN                  NaN
# 1985  672898206762672129                    NaN                  NaN
# 1991  672622327801233409                    NaN                  NaN
# 1992  672614745925664768                    NaN                  NaN
# 1995  672594978741354496                    NaN                  NaN
# 2002  672481316919734272                    NaN                  NaN
# 2009  672254177670729728                    NaN                  NaN
# 2015  672205392827572224                    NaN                  NaN
# 2017  672160042234327040                    NaN                  NaN
# 2141  669993076832759809                    NaN                  NaN
#
#                       timestamp  \
# 9     2017-07-26 15:59:51 +0000
# 12    2017-07-25 01:55:32 +0000
# 14    2017-07-24 17:02:04 +0000
# 25    2017-07-18 00:07:08 +0000
# 29    2017-07-15 23:25:31 +0000
# 43    2017-07-09 21:29:42 +0000
# 46    2017-07-07 16:22:55 +0000
# 49    2017-07-06 00:46:41 +0000
# 53    2017-07-03 16:04:48 +0000
# 54    2017-07-03 00:11:11 +0000
# 56    2017-07-02 15:32:16 +0000
# 61    2017-06-29 00:27:25 +0000
# 71    2017-06-25 00:45:22 +0000
# 78    2017-06-21 19:36:23 +0000
# 82    2017-06-19 16:24:33 +0000
# 83    2017-06-18 20:30:39 +0000
# 85    2017-06-17 16:52:05 +0000
# 92    2017-06-12 16:06:11 +0000
# 94    2017-06-11 21:18:31 +0000
# 97    2017-06-10 00:35:19 +0000
# 98    2017-06-09 16:22:42 +0000
# 99    2017-06-09 00:02:31 +0000
# 106   2017-06-06 00:01:46 +0000
# 107   2017-06-05 16:15:56 +0000
# 108   2017-06-04 23:56:03 +0000
# 110   2017-06-03 20:33:19 +0000
# 121   2017-05-30 16:49:31 +0000
# 129   2017-05-24 16:44:18 +0000
# 134   2017-05-22 16:06:55 +0000
# 135   2017-05-22 00:28:40 +0000
# ...                         ...
# 1897  2015-12-09 23:47:22 +0000
# 1900  2015-12-09 18:59:46 +0000
# 1903  2015-12-09 17:15:54 +0000
# 1907  2015-12-09 04:36:06 +0000
# 1915  2015-12-08 20:01:55 +0000
# 1921  2015-12-08 16:21:41 +0000
# 1928  2015-12-08 01:57:39 +0000
# 1930  2015-12-08 01:30:12 +0000
# 1936  2015-12-07 20:07:04 +0000
# 1937  2015-12-07 17:38:09 +0000
# 1945  2015-12-07 03:34:14 +0000
# 1948  2015-12-07 02:58:09 +0000
# 1954  2015-12-07 00:12:23 +0000
# 1956  2015-12-06 21:19:54 +0000
# 1960  2015-12-06 04:49:31 +0000
# 1967  2015-12-06 03:24:51 +0000
# 1970  2015-12-06 00:17:55 +0000
# 1974  2015-12-05 14:35:56 +0000
# 1977  2015-12-05 04:00:04 +0000
# 1980  2015-12-05 03:05:49 +0000
# 1981  2015-12-05 02:46:02 +0000
# 1985  2015-12-04 22:00:08 +0000
# 1991  2015-12-04 03:43:54 +0000
# 1992  2015-12-04 03:13:46 +0000
# 1995  2015-12-04 01:55:13 +0000
# 2002  2015-12-03 18:23:34 +0000
# 2009  2015-12-03 03:21:00 +0000
# 2015  2015-12-03 00:07:09 +0000
# 2017  2015-12-02 21:06:56 +0000
# 2141  2015-11-26 21:36:12 +0000
#
#                                                  source  \
# 9     <a href="http://twitter.com/download/iphone" r...
# 12    <a href="http://twitter.com/download/iphone" r...
# 14    <a href="http://twitter.com/download/iphone" r...
# 25    <a href="http://twitter.com/download/iphone" r...
# 29    <a href="http://twitter.com/download/iphone" r...
# 43    <a href="http://twitter.com/download/iphone" r...
# 46    <a href="http://twitter.com/download/iphone" r...
# 49    <a href="http://twitter.com/download/iphone" r...
# 53    <a href="http://twitter.com/download/iphone" r...
# 54    <a href="http://twitter.com/download/iphone" r...
# 56    <a href="http://twitter.com/download/iphone" r...
# 61    <a href="http://twitter.com/download/iphone" r...
# 71    <a href="http://twitter.com/download/iphone" r...
# 78    <a href="http://twitter.com/download/iphone" r...
# 82    <a href="http://twitter.com/download/iphone" r...
# 83    <a href="http://twitter.com/download/iphone" r...
# 85    <a href="http://twitter.com/download/iphone" r...
# 92    <a href="http://twitter.com/download/iphone" r...
# 94    <a href="http://twitter.com/download/iphone" r...
# 97    <a href="http://twitter.com/download/iphone" r...
# 98    <a href="http://twitter.com/download/iphone" r...
# 99    <a href="http://twitter.com/download/iphone" r...
# 106   <a href="http://twitter.com/download/iphone" r...
# 107   <a href="http://twitter.com/download/iphone" r...
# 108   <a href="http://twitter.com/download/iphone" r...
# 110   <a href="http://twitter.com/download/iphone" r...
# 121   <a href="http://twitter.com/download/iphone" r...
# 129   <a href="http://twitter.com/download/iphone" r...
# 134   <a href="http://twitter.com/download/iphone" r...
# 135   <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 1897  <a href="http://twitter.com/download/iphone" r...
# 1900  <a href="http://twitter.com/download/iphone" r...
# 1903  <a href="http://twitter.com/download/iphone" r...
# 1907  <a href="http://twitter.com/download/iphone" r...
# 1915  <a href="http://twitter.com/download/iphone" r...
# 1921  <a href="http://twitter.com/download/iphone" r...
# 1928  <a href="http://twitter.com/download/iphone" r...
# 1930  <a href="http://twitter.com/download/iphone" r...
# 1936  <a href="http://twitter.com/download/iphone" r...
# 1937  <a href="http://twitter.com/download/iphone" r...
# 1945  <a href="http://twitter.com/download/iphone" r...
# 1948  <a href="http://twitter.com/download/iphone" r...
# 1954  <a href="http://twitter.com/download/iphone" r...
# 1956  <a href="http://twitter.com/download/iphone" r...
# 1960  <a href="http://twitter.com/download/iphone" r...
# 1967  <a href="http://twitter.com/download/iphone" r...
# 1970  <a href="http://twitter.com/download/iphone" r...
# 1974  <a href="http://twitter.com/download/iphone" r...
# 1977  <a href="http://twitter.com/download/iphone" r...
# 1980  <a href="http://twitter.com/download/iphone" r...
# 1981  <a href="http://twitter.com/download/iphone" r...
# 1985  <a href="http://twitter.com/download/iphone" r...
# 1991  <a href="http://twitter.com/download/iphone" r...
# 1992  <a href="http://twitter.com/download/iphone" r...
# 1995  <a href="http://twitter.com/download/iphone" r...
# 2002  <a href="http://twitter.com/download/iphone" r...
# 2009  <a href="http://twitter.com/download/iphone" r...
# 2015  <a href="http://twitter.com/download/iphone" r...
# 2017  <a href="http://twitter.com/download/iphone" r...
# 2141  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 9     This is Cassie. She is a college pup. Studying...                    0
# 12    Here's a puppo that seems to be on the fence a...                    0
# 14    This is Stuart. He's sporting his favorite fan...                    0
# 25    This... is a Jubilant Antarctic House Bear. We...                    0
# 29    This is Roscoe. Another pupper fallen victim t...                    0
# 43    Meet Yogi. He doesn't have any important dog m...                    0
# 46    Meet Grizzwald. He may be the floofiest floofe...                    0
# 49    This is Gus. He's quite the cheeky pupper. Alr...                    0
# 53    This is Rey. He's a Benebop Cumberfloof. 12/10...                    0
# 54    This is Gary. He couldn't miss this puppertuni...                    0
# 56    Here is a pupper approaching maximum borkdrive...                    0
# 61    Meet Jesse. He's a Fetty Woof. His tongue ejec...                    0
# 71    This is Snoopy. He's a proud #PrideMonthPuppo....                    0
# 78    RT @rachel2195: @dog_rates the boyfriend and h...   876850772322988032
# 82    This is Ginger. She's having a ruff Monday. To...                    0
# 83    I can say with the pupmost confidence that the...                    0
# 85    Meet Venti, a seemingly caffeinated puppoccino...                    0
# 92    This is Jed. He may be the fanciest pupper in ...                    0
# 94    This is Sebastian. He can't see all the colors...                    0
# 97    RT @dog_rates: This is Sierra. She's one preci...   873213775632977920
# 98    This is Sierra. She's one precious pupper. Abs...                    0
# 99    Here's a very large dog. He has a date later. ...                    0
# 106   Say hello to Lassie. She's celebrating #PrideM...                    0
# 107   This is Rover. As part of pupper protocol he h...                    0
# 108   This is Napolean. He's a Raggedy East Nicaragu...                    0
# 110   Never doubt a doggo 14/10 https://t.co/AbBLh2FZCH                    0
# 121   This is Scout. He just graduated. Officially a...                    0
# 129   This is Shikha. She just watched you drop a sk...                    0
# 134   This is Lili. She can't believe you betrayed h...                    0
# 135   This is Jamesy. He gives a kiss to every other...                    0
# ...                                                 ...                  ...
# 1897  Meet Rufio. He is unaware of the pink legless ...                    0
# 1900  This is Rodman. He's getting destroyed by the ...                    0
# 1903  This pupper is fed up with being tickled. 12/1...                    0
# 1907  This pupper just wants a belly rub. This puppe...                    0
# 1915  This is Lennon. He's in quite the predicament....                    0
# 1921  This is Gus. He's super stoked about being an ...                    0
# 1928  Herd of wild dogs here. Not sure what they're ...                    0
# 1930  This is Kaiya. She's an aspiring shoe model. 1...                    0
# 1936  This is one esteemed pupper. Just graduated co...                    0
# 1937  This is Obie. He is on guard watching for evil...                    0
# 1945  This is Raymond. He's absolutely terrified of ...                    0
# 1948  This is Pickles. She's a tiny pointy pupper. A...                    0
# 1954  This is Albert AKA King Banana Peel. He's a ki...                    0
# 1956  This is Jeffri. He's a speckled ice pupper. Ve...                    0
# 1960  This little pupper can't wait for Christmas. H...                    0
# 1967  This is Django. He's a skilled assassin pupper...                    0
# 1970  Meet Eve. She's a raging alcoholic 8/10 (would...                    0
# 1974  This is Fletcher. He's had a ruff night. No mo...                    0
# 1977  This is Schnozz. He's had a blurred tail since...                    0
# 1980  This is Chuckles. He is one skeptical pupper. ...                    0
# 1981  This is Chet. He's having a hard time. Really ...                    0
# 1985  This is Cheryl AKA Queen Pupper of the Skies. ...                    0
# 1991  This lil pupper is sad because we haven't foun...                    0
# 1992  This is Norman. Doesn't bark much. Very docile...                    0
# 1995  Meet Scott. Just trying to catch his train to ...                    0
# 2002  Say hello to Jazz. She should be on the cover ...                    0
# 2009  This is Rolf. He's having the time of his life...                    0
# 2015  This is Opal. He's a Royal John Coctostan. Rea...                    0
# 2017  This is Bubba. He's a Titted Peebles Aorta. Ev...                    0
# 2141  This is Zoey. Her dreams of becoming a hippo b...                    0
#
#       retweeted_status_user_id retweeted_status_timestamp       name  ...  \
# 9                          NaN                        NaN     Cassie  ...
# 12                         NaN                        NaN       None  ...
# 14                         NaN                        NaN     Stuart  ...
# 25                         NaN                        NaN       None  ...
# 29                         NaN                        NaN     Roscoe  ...
# 43                         NaN                        NaN       Yogi  ...
# 46                         NaN                        NaN  Grizzwald  ...
# 49                         NaN                        NaN        Gus  ...
# 53                         NaN                        NaN        Rey  ...
# 54                         NaN                        NaN       Gary  ...
# 56                         NaN                        NaN          a  ...
# 61                         NaN                        NaN      Jesse  ...
# 71                         NaN                        NaN     Snoopy  ...
# 78                5.128045e+08  2017-06-19 17:14:49 +0000       None  ...
# 82                         NaN                        NaN     Ginger  ...
# 83                         NaN                        NaN       None  ...
# 85                         NaN                        NaN      Venti  ...
# 92                         NaN                        NaN        Jed  ...
# 94                         NaN                        NaN  Sebastian  ...
# 97                4.196984e+09  2017-06-09 16:22:42 +0000     Sierra  ...
# 98                         NaN                        NaN     Sierra  ...
# 99                         NaN                        NaN       None  ...
# 106                        NaN                        NaN     Lassie  ...
# 107                        NaN                        NaN      Rover  ...
# 108                        NaN                        NaN   Napolean  ...
# 110                        NaN                        NaN       None  ...
# 121                        NaN                        NaN      Scout  ...
# 129                        NaN                        NaN     Shikha  ...
# 134                        NaN                        NaN       Lili  ...
# 135                        NaN                        NaN     Jamesy  ...
# ...                        ...                        ...        ...  ...
# 1897                       NaN                        NaN      Rufio  ...
# 1900                       NaN                        NaN     Rodman  ...
# 1903                       NaN                        NaN       None  ...
# 1907                       NaN                        NaN       None  ...
# 1915                       NaN                        NaN     Lennon  ...
# 1921                       NaN                        NaN        Gus  ...
# 1928                       NaN                        NaN       None  ...
# 1930                       NaN                        NaN      Kaiya  ...
# 1936                       NaN                        NaN        one  ...
# 1937                       NaN                        NaN       Obie  ...
# 1945                       NaN                        NaN    Raymond  ...
# 1948                       NaN                        NaN    Pickles  ...
# 1954                       NaN                        NaN     Albert  ...
# 1956                       NaN                        NaN     Jeffri  ...
# 1960                       NaN                        NaN       None  ...
# 1967                       NaN                        NaN     Django  ...
# 1970                       NaN                        NaN        Eve  ...
# 1974                       NaN                        NaN   Fletcher  ...
# 1977                       NaN                        NaN    Schnozz  ...
# 1980                       NaN                        NaN   Chuckles  ...
# 1981                       NaN                        NaN       Chet  ...
# 1985                       NaN                        NaN     Cheryl  ...
# 1991                       NaN                        NaN       None  ...
# 1992                       NaN                        NaN     Norman  ...
# 1995                       NaN                        NaN      Scott  ...
# 2002                       NaN                        NaN       Jazz  ...
# 2009                       NaN                        NaN       Rolf  ...
# 2015                       NaN                        NaN       Opal  ...
# 2017                       NaN                        NaN      Bubba  ...
# 2141                       NaN                        NaN       Zoey  ...
#
#       pupper  puppo                                    dog_picture_url  \
# 9                       http://pbs.twimg.com/media/DFrEyVuW0AAO3t9.jpg
# 12            puppo     http://pbs.twimg.com/media/DFi579UWsAAatzw.jpg
# 14            puppo     http://pbs.twimg.com/media/DFg_2PVW0AEHN3p.jpg
# 25                      http://pbs.twimg.com/media/DE-eAq6UwAA-jaE.jpg
# 29    pupper            http://pbs.twimg.com/media/DE0BTnQUwAApKEH.jpg
# 43                      http://pbs.twimg.com/media/DEUtQbzW0AUTv_o.jpg
# 46                      http://pbs.twimg.com/media/DEJT3FeXoAAtwUy.jpg
# 49    pupper            http://pbs.twimg.com/media/DEAz_HHXsAA-p_z.jpg
# 53                      http://pbs.twimg.com/media/DD0pWm9XcAAeSBL.jpg
# 54                      http://pbs.twimg.com/media/DDxPFwbWAAEbVVR.jpg
# 56    pupper         http://pbs.twimg.com/ext_tw_video_thumb/881535...
# 61                      http://pbs.twimg.com/media/DDcscbXU0AIfDzs.jpg
# 71            puppo     http://pbs.twimg.com/media/DDIKMXxXcAAbmdp.jpg
# 78    pupper            http://pbs.twimg.com/media/DCszHgmW0AAmIpT.jpg
# 82    pupper            http://pbs.twimg.com/media/DCsnnZsVwAEfkyi.jpg
# 83                                                                None
# 85                      http://pbs.twimg.com/media/DCiavj_UwAAcXep.jpg
# 92    pupper            http://pbs.twimg.com/media/DCIgSR0XgAANEOY.jpg
# 94            puppo     http://pbs.twimg.com/media/DCEeLxmW0AAHXNk.jpg
# 97    pupper            http://pbs.twimg.com/media/DB5HTBGXUAE0TiK.jpg
# 98    pupper            http://pbs.twimg.com/media/DB5HTBGXUAE0TiK.jpg
# 99                      http://pbs.twimg.com/media/DB1m871XkAUbCkY.jpg
# 106                     http://pbs.twimg.com/media/DBmKAmBXUAE-pQ-.jpg
# 107   pupper            http://pbs.twimg.com/media/DBkfY59XgAUK52d.jpg
# 108                     http://pbs.twimg.com/media/DBg_HT8XUAEoyo_.jpg
# 110                                                               None
# 121                     http://pbs.twimg.com/media/DBFtiYqWAAAsjj1.jpg
# 129           puppo     http://pbs.twimg.com/media/DAmyy8FXYAIH8Ty.jpg
# 134                     http://pbs.twimg.com/media/DAcXEWuXkAIBDGJ.jpg
# 135   pupper            http://pbs.twimg.com/media/DAZAUfBXYAAHtni.jpg
# ...      ...    ...                                                ...
# 1897  pupper            http://pbs.twimg.com/media/CV0l10AU8AAfg-a.jpg
# 1900                    http://pbs.twimg.com/media/CVzkA7-WsAAcXz6.jpg
# 1903  pupper            http://pbs.twimg.com/media/CVzMPh1UsAELQ_p.jpg
# 1907  pupper            http://pbs.twimg.com/media/CVweVUfW4AACPwI.jpg
# 1915  pupper            http://pbs.twimg.com/media/CVuopr8WwAExw_T.jpg
# 1921  pupper            http://pbs.twimg.com/media/CVt2PawWIAEUkqW.jpg
# 1928                    http://pbs.twimg.com/media/CVqwedgXIAEAT6A.jpg
# 1930  pupper            http://pbs.twimg.com/media/CVqqMtiVEAEye_L.jpg
# 1936  pupper            http://pbs.twimg.com/media/CVpgPGwWoAEV7gG.jpg
# 1937  pupper            http://pbs.twimg.com/media/CVo-JuMWwAAet6F.jpg
# 1945  pupper            http://pbs.twimg.com/media/CVl8_EPWoAAcuSC.jpg
# 1948  pupper            http://pbs.twimg.com/media/CVl0vFeWoAAMTfg.jpg
# 1954  pupper            http://pbs.twimg.com/media/CVlOy3pW4AQ9H1K.jpg
# 1956  pupper            http://pbs.twimg.com/media/CVknUTlVEAARjU5.jpg
# 1960  pupper            http://pbs.twimg.com/media/CVhEoq4WcAE8pBm.jpg
# 1967  pupper            http://pbs.twimg.com/media/CVgxQc5XIAAYL0W.jpg
# 1970  pupper            http://pbs.twimg.com/media/CVgGc9hWIAIe1bn.jpg
# 1974  pupper            http://pbs.twimg.com/media/CVeBQwiUsAAqhLw.jpg
# 1977  pupper            http://pbs.twimg.com/media/CVbvjKqW4AA_CuD.jpg
# 1980  pupper            http://pbs.twimg.com/media/CVbjRSIWsAElw2s.jpg
# 1981  pupper            http://pbs.twimg.com/media/CVbeyGUU8AEq300.jpg
# 1985  pupper            http://pbs.twimg.com/media/CVadWcCXIAAL4Sh.jpg
# 1991  pupper            http://pbs.twimg.com/media/CVWicBbUYAIomjC.jpg
# 1992  pupper            http://pbs.twimg.com/media/CVWbitUW4AAzclx.jpg
# 1995  pupper            http://pbs.twimg.com/media/CVWJkJXWsAInlZl.jpg
# 2002  pupper            http://pbs.twimg.com/media/CVUiMUeW4AEQgkU.jpg
# 2009  pupper            http://pbs.twimg.com/media/CVRTmz1WcAA4uMF.jpg
# 2015  pupper            http://pbs.twimg.com/media/CVQnPMrVAAAzShR.jpg
# 2017  pupper            http://pbs.twimg.com/media/CVP9_beUEAAwURR.jpg
# 2141                    http://pbs.twimg.com/media/CUxLJO8U8AAu6Zu.jpg
#
#                                           tweet_web_url favourite_count  \
# 9     https://twitter.com/dog_rates/status/890240255...         30873.0
# 12    https://twitter.com/dog_rates/status/889665388...         46509.0
# 14    https://twitter.com/dog_rates/status/889531135...         14628.0
# 25    https://twitter.com/dog_rates/status/887101392...         29581.0
# 29    https://twitter.com/dog_rates/status/886366144...         20483.0
# 43    https://twitter.com/dog_rates/status/884162670...         19706.0
# 46    https://twitter.com/dog_rates/status/883360690...         21957.0
# 49    https://twitter.com/dog_rates/status/882762694...         27361.0
# 53    https://twitter.com/dog_rates/status/881906580...         23528.0
# 54    https://twitter.com/dog_rates/status/881666595...         48983.0
# 56    https://twitter.com/dog_rates/status/881536004...         47823.0
# 61    https://twitter.com/dog_rates/status/880221127...         26148.0
# 71    https://twitter.com/dog_rates/status/878776093...         18786.0
# 78    https://twitter.com/rachel2195/status/87685077...          1787.0
# 82    https://twitter.com/dog_rates/status/876838120...         20054.0
# 83    https://twitter.com/dog_rates/status/830583320...         22835.0
# 85    https://twitter.com/dog_rates/status/876120275...         27078.0
# 92    https://twitter.com/dog_rates/status/874296783...         25278.0
# 94    https://twitter.com/dog_rates/status/874012996...         33509.0
# 97    https://twitter.com/dog_rates/status/830583320...          7010.0
# 98    https://twitter.com/dog_rates/status/873213775...          7010.0
# 99    https://twitter.com/dog_rates/status/872967104...         26523.0
# 106   https://twitter.com/dog_rates/status/871879754...         36807.0
# 107   https://twitter.com/dog_rates/status/871762521...         19731.0
# 108   https://twitter.com/dog_rates/status/871515927...         19642.0
# 110   https://twitter.com/dog_rates/status/830583320...         20392.0
# 121   https://twitter.com/dog_rates/status/869596645...         15623.0
# 129   https://twitter.com/dog_rates/status/867421006...         15803.0
# 134   https://twitter.com/dog_rates/status/866686824...         18927.0
# 135   https://twitter.com/dog_rates/status/866450705...        120097.0
# ...                                                 ...             ...
# 1897  https://twitter.com/dog_rates/status/674737130...           648.0
# 1900  https://twitter.com/dog_rates/status/674664755...           927.0
# 1903  https://twitter.com/dog_rates/status/674638615...          1692.0
# 1907  https://twitter.com/dog_rates/status/674447403...          1066.0
# 1915  https://twitter.com/dog_rates/status/674318007...          1427.0
# 1921  https://twitter.com/dog_rates/status/674262580...          1306.0
# 1928  https://twitter.com/dog_rates/status/674045139...          1425.0
# 1930  https://twitter.com/dog_rates/status/674038233...          1107.0
# 1936  https://twitter.com/dog_rates/status/673956914...          1953.0
# 1937  https://twitter.com/dog_rates/status/673919437...          1169.0
# 1945  https://twitter.com/dog_rates/status/673707060...          1100.0
# 1948  https://twitter.com/dog_rates/status/673697980...          3800.0
# 1954  https://twitter.com/dog_rates/status/673656262...           720.0
# 1956  https://twitter.com/dog_rates/status/673612854...          1596.0
# 1960  https://twitter.com/dog_rates/status/673363615...          1025.0
# 1967  https://twitter.com/dog_rates/status/673342308...          1270.0
# 1970  https://twitter.com/dog_rates/status/673295268...          7523.0
# 1974  https://twitter.com/dog_rates/status/673148804...          1683.0
# 1977  https://twitter.com/dog_rates/status/672988786...           984.0
# 1980  https://twitter.com/dog_rates/status/672975131...          1679.0
# 1981  https://twitter.com/dog_rates/status/672970152...           943.0
# 1985  https://twitter.com/dog_rates/status/672898206...           905.0
# 1991  https://twitter.com/dog_rates/status/672622327...          1297.0
# 1992  https://twitter.com/dog_rates/status/672614745...          1222.0
# 1995  https://twitter.com/dog_rates/status/672594978...          1330.0
# 2002  https://twitter.com/dog_rates/status/672481316...           717.0
# 2009  https://twitter.com/dog_rates/status/672254177...          1427.0
# 2015  https://twitter.com/dog_rates/status/672205392...          2260.0
# 2017  https://twitter.com/dog_rates/status/672160042...           872.0
# 2141  https://twitter.com/dog_rates/status/669993076...           325.0
#
#      retweet_count  rating_numerator  rating_denominator  dog_stages  \
# 9           7078.0              14.0                10.0       doggo
# 12          9627.0              13.0                10.0       puppo
# 14          2163.0              13.0                10.0       puppo
# 25          5723.0              12.0                10.0
# 29          3071.0              12.0                10.0      pupper
# 43          2869.0              12.0                10.0       doggo
# 46          3561.0              13.0                10.0     floofer
# 49          4712.0              12.0                10.0      pupper
# 53          3271.0              12.0                10.0
# 54         10269.0              13.0                10.0
# 56         15348.0              14.0                10.0      pupper
# 61          4059.0              12.0                10.0
# 71          3975.0              13.0                10.0       puppo
# 78            77.0              14.0                10.0      pupper
# 82          3220.0              12.0                10.0      pupper
# 83          4481.0              14.0                10.0
# 85          4506.0              13.0                10.0
# 92          3981.0              13.0                10.0      pupper
# 94         10068.0              13.0                10.0       puppo
# 97          1536.0              12.0                10.0      pupper
# 98          1536.0              12.0                10.0      pupper
# 99          5251.0              12.0                10.0       doggo
# 106        10832.0              13.0                10.0
# 107         3389.0              12.0                10.0      pupper
# 108         3363.0              12.0                10.0       doggo
# 110         5380.0              14.0                10.0       doggo
# 121         3068.0              12.0                10.0       doggo
# 129         2455.0              12.0                10.0       puppo
# 134         3423.0              12.0                10.0
# 135        34783.0              13.0                10.0      pupper
# ...            ...               ...                 ...         ...
# 1897          96.0              10.0                10.0      pupper
# 1900         260.0              10.0                10.0
# 1903         594.0              12.0                10.0      pupper
# 1907         363.0              10.0                10.0      pupper
# 1915         525.0               8.0                10.0      pupper
# 1921         463.0               9.0                10.0      pupper
# 1928         649.0               3.0                10.0
# 1930         422.0              12.0                10.0      pupper
# 1936         972.0              10.0                10.0      pupper
# 1937         376.0              11.0                10.0      pupper
# 1945         398.0              10.0                10.0      pupper
# 1948        1981.0               8.0                10.0      pupper
# 1954         246.0              10.0                10.0      pupper
# 1956         731.0               7.0                10.0      pupper
# 1960         309.0              11.0                10.0      pupper
# 1967         592.0              10.0                10.0      pupper
# 1970        3193.0               8.0                10.0      pupper
# 1974         639.0               8.0                10.0      pupper
# 1977         296.0              10.0                10.0      pupper
# 1980         916.0              10.0                10.0      pupper
# 1981         361.0               7.0                10.0      pupper
# 1985         428.0              11.0                10.0      pupper
# 1991         496.0              12.0                10.0      pupper
# 1992         592.0               6.0                10.0      pupper
# 1995         614.0               9.0                10.0      pupper
# 2002         126.0              12.0                10.0      pupper
# 2009         750.0              11.0                10.0      pupper
# 2015        1165.0               9.0                10.0      pupper
# 2017         360.0               8.0                10.0      pupper
# 2141          86.0               9.0                10.0
#
#       dog_stages_alt
# 9              doggo
# 12             puppo
# 14             puppo
# 25             floof
# 29            pupper
# 43             doggo
# 46             floof
# 49            pupper
# 53             floof
# 54            pupper
# 56            pupper
# 61              blep
# 71             puppo
# 78            pupper
# 82            pupper
# 83             doggo
# 85             puppo
# 92            pupper
# 94             puppo
# 97            pupper
# 98            pupper
# 99             doggo
# 106            puppo
# 107           pupper
# 108            doggo
# 110            doggo
# 121            doggo
# 129            puppo
# 134            puppo
# 135           pupper
# ...              ...
# 1897          pupper
# 1900          pupper
# 1903          pupper
# 1907          pupper
# 1915          pupper
# 1921          pupper
# 1928          pupper
# 1930          pupper
# 1936          pupper
# 1937          pupper
# 1945          pupper
# 1948          pupper
# 1954          pupper
# 1956          pupper
# 1960          pupper
# 1967          pupper
# 1970          pupper
# 1974          pupper
# 1977          pupper
# 1980          pupper
# 1981          pupper
# 1985          pupper
# 1991          pupper
# 1992          pupper
# 1995          pupper
# 2002          pupper
# 2009          pupper
# 2015          pupper
# 2017          pupper
# 2141          pupper
#
# [445 rows x 22 columns]

# %%
tweet_clean.loc[61].values
# Out:
# array([880221127280381952, nan, nan, '2017-06-29 00:27:25 +0000',
#        '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#        "Meet Jesse. He's a Fetty Woof. His tongue ejects without warning. A true bleptomaniac. 12/10 would snug well https://t.co/fUod0tVmvK",
#        0, nan, nan, 'Jesse', '', '', '', '',
#        'http://pbs.twimg.com/media/DDcscbXU0AIfDzs.jpg',
#        'https://twitter.com/dog_rates/status/880221127280381952/photo/1',
#        26148.0, 4059.0, 12.0, 10.0, '', 'blep'], dtype=object)
